# %% [markdown]
# ___
# ### Youtube Data Crawling
# - video title
# - channel name
# - script
#
# **::VPN 연결한 상태에서 진행하면 ConnectionError 발생 빈도가 줄어듭니다::**

# %%
import os

# pip install necessary library
os.system('pip install --upgrade pip')
library = " ".join(['numpy', 'pandas', 'tqdm', 'requests', 'beautifulsoup4', 'user-agent', 'youtube_transcript_api', 'lxml', 'pyopenssl', 'ndg-httpsclient', 'pyasn1'])
os.system(f'pip install {library}')

import re
import time
import numpy as np
import pandas as pd
from tqdm.autonotebook import tqdm

import requests
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
from user_agent import generate_user_agent

from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api import TranscriptsDisabled
# Out:
# Requirement already satisfied: pip in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (22.1.2)
# Requirement already satisfied: numpy in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (1.21.2)
# Requirement already satisfied: pandas in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: tqdm in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (4.64.0)
# Requirement already satisfied: requests in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: user-agent in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (0.1.10)
# Requirement already satisfied: youtube_transcript_api in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (0.4.4)
# Requirement already satisfied: lxml in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: pyopenssl in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (22.0.0)
# Requirement already satisfied: ndg-httpsclient in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: pyasn1 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (0.4.8)
# Requirement already satisfied: pytz>=2020.1 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from requests) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.8)
# Requirement already satisfied: soupsieve>1.2 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: six in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from user-agent) (1.16.0)
# Requirement already satisfied: cryptography>=35.0 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from pyopenssl) (37.0.2)
# Requirement already satisfied: cffi>=1.12 in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=35.0->pyopenssl) (1.15.0)
# Requirement already satisfied: pycparser in /Users/mycelebs_95/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=35.0->pyopenssl) (2.21)

# %%
def scrape_transcripts(url: str) -> tuple:
    ''' 유튜브 스크립트 스크레이핑 함수 
    
    :: input data
        * url: 유튜브 링크
        
    :: output data
        * script: 유튜브 스크립트 
    '''
    
    video_id = url[url.find('v=')+2:]
    try:
        userAgent = generate_user_agent(os=('mac', 'linux'), navigator='chrome', device_type='desktop')
        headers = {'user-agent': userAgent}
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id, proxies=headers)
        status = 200
        
        for transcript in transcript_list:
            # fetch the actual transcript data
            transcripts = transcript.fetch()

            
            script = ""
            for transcript in transcripts:
                script += transcript['text'] + " "
                
        script = re.sub(' +', ' ', script).strip()

        if script == "":
            status = -1
            script = np.nan
            
    except TranscriptsDisabled:
        # 재생 불가 동영상 or 스크립트 누락 동영상
        status = -1
        script = np.nan
        
    except ConnectionError as e:
        # ConnectionError
        status = 403
        print(e, status, '\ntime sleep: 300sec')
        script = np.nan
        time.sleep(300)
        
    return status, video_id, script

# %%
def parsing_url(url: str) -> tuple:
    ''' Parsing url & scraping tite, channel_name'''
    
    try:
        # url pasing & user agent
        userAgent = generate_user_agent(os=('mac', 'linux'), navigator='chrome', device_type='desktop')
        headers = {'user-agent': userAgent}
        html = requests.get(url, headers=headers)
        status = html.status_code
    except ConnectionError as e:
        status = 404
        print(e, status, '\ntime sleep: 300sec')
        title, channel_name = np.nan, np.nan
        time.sleep(300)
    
    if status == 200:
        try:
            # scraping title & channel_name
            soup = BeautifulSoup(html.text, 'lxml')
            title = soup.find('title').text.replace('- YouTube', '').strip()
            channel_name = soup.find('div', 'watch-main-col').find('link', {'itemprop': 'name'})['content']   
            
            # thumbnail image
            if soup.find('link', {'rel': 'image_src'}) == None:
                thumbnail_img = np.nan
            else:
                thumbnail_img = soup.find('link', {'rel': 'image_src'})['href']

            # youtuber profile image
            reg = re.compile(r'https\:\/\/yt3\.ggpht\.com\/[a-zA-Z0-9\-\_\/]+\=s48\-c\-k\-c0x00ffffff\-no\-rj')
            if re.search(reg, html.text) == None:
                profile_img = np.nan
            else:
                profile_img = re.search(reg, html.text).group(0)
                
        except AttributeError:
            # scraping failed
            status = -1
            title, channel_name, thumbnail_img, profile_img = np.nan, np.nan, np.nan, np.nan
            
    else:
        title, channel_name, thumbnail_img, profile_img = np.nan, np.nan, np.nan, np.nan
        
    return status, title, channel_name, thumbnail_img, profile_img

# %%
def crawling_youtube(urls: list) -> pd.DataFrame:
    ''' 유튜브 데이터 크롤링 실행함수 
    
    :: input data
        * urls: 유튜브 링크 리스트
        
    :: output data
        * scrape_df: 데이터 크롤링 완료 데이터프레임
    '''
    # url dedup
    urls = list(set(urls))
    
    scrapes, error = [], []
    for url in tqdm(urls):

        ''' status
            * 200: url pasing successful
            * 404: url pasing failed
            * 403: url pasing failed
            *  -1: scraping failed
        '''
        status, title, channel_name, thumbnail_img, profile_img = parsing_url(url)
        status, video_id, script = scrape_transcripts(url)

        if (status == 404) | (status == 403):
            error.append(url)
        else:
            scrapes.append([url, title, video_id, channel_name, script, thumbnail_img, profile_img, status])
    
    # error: Re Crawling
    for url in tqdm(error):
        status, title, channel_name, thumbnail_img, profile_img = parsing_url(url)
        script = scrape_transcripts(url)
        scrapes.append([url, title, video_id, channel_name, script, thumbnail_img, profile_img, status])
        
    scrape_df = pd.DataFrame(scrapes, columns=['url', 'title', 'video_id', 'youtuber', 'script', 'thumbnail', 'youtuber_profile', 'status'])
    
    # # Extract only English scripts
    # reg_eng = re.compile('[^a-z^A-Z^0-9^가-힣^\.^!^,^\?^\'^\[^\]^\-^\(^\) ]')
    # scrape_df = scrape_df[scrape_df.script.str.contains(reg_eng, na=False)==False].reset_index(drop=True)
    # _scrape_df = scrape_df[scrape_df.script.str.contains(reg_eng, na=False)].reset_index(drop=True)
    
    return scrape_df

# %%
urls = '{input data: 유튜브 링크 url 리스트}'

df = pd.read_excel('/Users/mycelebs_95/Downloads/Beauty_full_final.xlsx')
urls = df.URL.unique().tolist()

# %%
# Start Crawling 
scrape_df = crawling_youtube(urls)
# Out:
#   0%|          | 0/921 [00:00<?, ?it/s]
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')) 403
# time sleep: 300sec
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')) 404
# time sleep: 300sec
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')) 404
# time sleep: 300sec
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
urls = scrape_df.loc[scrape_df.status==-1, 'url'].tolist()
scrape_df_att_err = crawling_youtube(urls)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
''' Script Preprocessing '''

_scrape_df = scrape_df.copy()

# 영문, 특수기호(,.!?')만 추출
reg_eng = re.compile('[^a-zA-Z0-9\.\,\?\!\']')
_scrape_df.loc[:, 'script'] = scrape_df.script.str.replace(reg_eng, ' ').str.replace(' +', ' ')

# 특수기호와 영문 빈도 계산 및 비율 비교를 통한 필터링
_scrape_df_copy = _scrape_df.copy()
_scrape_df_copy.loc[:, 'en'] = _scrape_df_copy.script.str.count('[a-zA-Z]')
_scrape_df_copy.loc[:, 'sp_0'] = _scrape_df_copy.script.str.count('\.')
_scrape_df_copy.loc[:, 'sp_1'] = _scrape_df_copy.script.str.count('\,')
_scrape_df_copy.loc[:, 'sp_2'] = _scrape_df_copy.script.str.count('\?')
_scrape_df_copy.loc[:, 'sp_3'] = _scrape_df_copy.script.str.count('\!')

drop_index = []
for i in range(len(_scrape_df_copy)):
    counts = _scrape_df_copy.iloc[i, -5:].tolist()
    
    if str(counts[0]) == 'nan':
        pass
    else:
        if counts.index(max(counts)) != 0:
            drop_index.append(i)
        elif counts[0] <= sum(counts[1:]) * 13:
            drop_index.append(i)
        else:
            pass

_scrape_df_copy_ = _scrape_df_copy.drop(drop_index).sort_values('youtuber').reset_index(drop=True)

# Upload table into Database
columns = ['url', 'video_title', 'thumbnail', 'youtuber', 'youtuber_profile', 'script']
upload_df =  _scrape_df_copy_.loc[:, columns]

# %%
import os
import re
import sys
import time
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from user_agent import generate_user_agent
from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException

import requests
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
from user_agent import generate_user_agent

from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api import TranscriptsDisabled

import socket
import warnings
warnings.filterwarnings("ignore")

from src.crawling.crawler import get_url, scroll_down
from src.crawling.crawler_youtube import CrawlingYoutube

# %%
def get_url(url, window=True, image=True):
    ''' Set up webdriver, useragent & Get url '''
    
    wd = None
    socket.setdefaulttimeout(30)
    error = []
    attempts = 0 # url parsing 시도횟수
    # 10번 이상 parsing 실패시 pass
    while attempts < 10:
        try:  
            attempts += 1
            # user agent
            options = Options() 
            userAgent = generate_user_agent(os=('mac', 'linux'), navigator='chrome', device_type='desktop')
            options.add_argument('window-size=1920x1080')
            options.add_argument("--disable-gpu")
            options.add_argument('--disable-extensions')
            if not window:
                options.add_argument('headless')
            if not image:
                options.add_argument('--blink-settings=imagesEnabled=false')
            options.add_argument(f'user-agent={userAgent}')

            # web driver 
            wd = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
            wd.get(url)
            wd.implicitly_wait(5)
            break

        # 예외처리
        except Exception as e:
            print(f'\n\nError: {str(e)}\n\n')
            time.sleep(300)
            try:
                wd.quit()
            except:
                pass
            wd = None
    return wd

def scroll_down(wd):
    ''' 
    Scroll down to the bottom of the page 
    ** 데스크탑 웹 페이지에서만 사용가능 **
    '''
    
    prev_height = wd.execute_script("return document.body.scrollHeight")
    while True:
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        # wd.implicitly_wait(5)
        time.sleep(1)
        current_height = wd.execute_script("return document.body.scrollHeight")

        if prev_height == current_height:
            break
        prev_height = current_height

# %%
# searching_word = 'ulta haul'
searching_word = 'sephora makeup'

searching_word = searching_word.replace(' ', '+')
filter_query = 'sp=EgYIBBABKAE%253D'
search_url = f'https://www.youtube.com/results?search_query={searching_word}&{filter_query}'
wd  = get_url(search_url, window=False, image=False)

try:
    xpath_filter = '//*[@id="container"]/ytd-toggle-button-renderer/a'
    WebDriverWait(wd, 15).until(EC.element_to_be_clickable((By.XPATH, xpath_filter)))
    # wd.find_element_by_xpath(xpath_filter).click()
except TimeoutException as e:
    print(e)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
# scroll down
cnt = 0
while True:
    height = wd.execute_script("return document.body.scrollHeight")
    wd.find_element_by_tag_name('body').send_keys(Keys.END)
    time.sleep(5)
    if int(height) == 0:
        cnt += 1
        if cnt == 50:
            break

# %%
# scraping video id (href)
soup = BeautifulSoup(wd.page_source, 'lxml')
url_a = soup.find_all('a', 'yt-simple-endpoint style-scope ytd-video-renderer')
urls = []
for a in tqdm(url_a):
    _id = a['href']
    url = f'https://www.youtube.com{_id}'
    urls.append(url)
wd.quit()
# Out:
# 100%|██████████| 424/424 [00:00<00:00, 655263.41it/s]

# %%
# searching_word = 'ulta haul'
searching_word = 'sephora makeup'

def crawling_url(searching_word):
    searching_word = searching_word.replace(' ', '+')
    filter_query = 'sp=EgYIBBABKAE%253D'
    search_url = f'https://www.youtube.com/results?search_query={searching_word}&{filter_query}'
    wd = get_url(search_url, window=False, image=False)

    try:
        xpath_filter = '//*[@id="container"]/ytd-toggle-button-renderer/a'
        WebDriverWait(wd, 15).until(EC.element_to_be_clickable((By.XPATH, xpath_filter)))
    except TimeoutException:
        wd.quit()
        wd = None
    except Exception as e:
        print(e)
        wd = None
        
    if wd == None:
        pass
    else:
        # page scroll down
        wd = scroll_down(wd, sleep_time=5, check_count=50)
        
        # scraping video id (href)
        soup = BeautifulSoup(wd.page_source, 'lxml')
        url_a = soup.find_all('a', 'yt-simple-endpoint style-scope ytd-video-renderer')
        urls = []
        for a in url_a:
            _id = a['href']
            url = f'https://www.youtube.com{_id}'
            urls.append(url)
    return urls

# %%
crw = CrawlingYoutube()
makeup = ['sephora makeup', 'ulta makeup', 'sephora makeup tutorial', 'ulta makeup tutorial'] + ['sephora haul', 'sephora sale', 'ulta haul', 'ulta sale', 'sephora review', 'ulta review']

urls, error = [], []
for s in tqdm(makeup):
    url, status = crw.crawling_url(searching_word)
    if status == 1:
        urls += url
    else:
        error.append(s)

error_ = []
for s in tqdm(error):
    urls += crw.crawling_url(searching_word)[0]
    error_.append(s)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  10%|█         | 1/10 [04:22<39:23, 262.59s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  20%|██        | 2/10 [08:42<34:48, 261.12s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  30%|███       | 3/10 [13:02<30:22, 260.41s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  40%|████      | 4/10 [17:22<26:02, 260.41s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  50%|█████     | 5/10 [21:42<21:41, 260.26s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  60%|██████    | 6/10 [26:02<17:20, 260.12s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  70%|███████   | 7/10 [30:23<13:00, 260.32s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  80%|████████  | 8/10 [34:42<08:40, 260.10s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#  90%|█████████ | 9/10 [39:02<04:20, 260.11s/it]
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# 100%|██████████| 10/10 [43:23<00:00, 260.40s/it]
# 0it [00:00, ?it/s]

# %%
len(set(urls))
# Out:
# 466

# %% [markdown]
# ___
# ### Test: Crawling Youtube Data

# %%
from tqdm.auto import tqdm
from src.crawling.crawler import *
from src.crawling.crawler_youtube import CrawlingYoutube

# %%
crw = CrawlingYoutube()

makeup = ['sephora makeup', 'ulta makeup', 'sephora makeup tutorial', 'ulta makeup tutorial']
info = ['sephora haul', 'sephora sale', 'ulta haul', 'ulta sale', 'sephora review', 'ulta review']
skincare = ['sephora skincare', 'ulta skincare']
fragrance = ['sephora fragrance', 'ulta fragrance']        
searching_words = makeup + info + skincare + fragrance

# %%
urls, error_word = [], []
for word in tqdm(searching_words):
    url, status = crw.crawling_url(word)
    
    if status == 1:
        urls += url
    else:
        error_word.append(word)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/mycelebs_95/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
urls = list(set(urls))
urls
# Out:
# ['https://www.youtube.com/watch?v=-MHUrmlE1TQ',
#  'https://www.youtube.com/watch?v=Ze637H39a6s',
#  'https://www.youtube.com/shorts/aT7weMFi-rk',
#  'https://www.youtube.com/watch?v=zlHBymgX_0Q',
#  'https://www.youtube.com/watch?v=9iL6P4oF5Xg',
#  'https://www.youtube.com/watch?v=cnblLm1dzwA',
#  'https://www.youtube.com/watch?v=_1iYWNdrHzw',
#  'https://www.youtube.com/watch?v=3rLm_aRjaoQ',
#  'https://www.youtube.com/watch?v=RJ_rO5osxWE',
#  'https://www.youtube.com/watch?v=KdutCtLeAEQ',
#  'https://www.youtube.com/watch?v=RPhy6Q52DIA',
#  'https://www.youtube.com/watch?v=Sl6dk7zaWgQ',
#  'https://www.youtube.com/watch?v=j9WJBwE1CKI',
#  'https://www.youtube.com/watch?v=CgS4Nc0sDOE',
#  'https://www.youtube.com/watch?v=ifa0ztghOQw',
#  'https://www.youtube.com/watch?v=hvUKD4iTGy4',
#  'https://www.youtube.com/watch?v=ctTSH_HOBg0',
#  'https://www.youtube.com/watch?v=LM91i5bnYSg',
#  'https://www.youtube.com/watch?v=nGNXjU2yPu0',
#  'https://www.youtube.com/watch?v=eN1PmKH9ABk',
#  'https://www.youtube.com/watch?v=NgOuUN6QoCc',
#  'https://www.youtube.com/watch?v=N8-A1S6O_TM',
#  'https://www.youtube.com/watch?v=C79Mf14xArI',
#  'https://www.youtube.com/watch?v=nFvyRs76NU4',
#  'https://www.youtube.com/watch?v=sZ7vpnq7zTc',
#  'https://www.youtube.com/watch?v=lIoycqcVhGQ',
#  'https://www.youtube.com/watch?v=RparzgEQhhw',
#  'https://www.youtube.com/watch?v=QEalSigjsl4',
#  'https://www.youtube.com/watch?v=sQDGG-nlB6g',
#  'https://www.youtube.com/watch?v=XnMW5jV3Ghk',
#  'https://www.youtube.com/watch?v=6keYh6Bsf08',
#  'https://www.youtube.com/watch?v=mzIBo2JVOww',
#  'https://www.youtube.com/watch?v=jj2TDk2mmBw',
#  'https://www.youtube.com/watch?v=HCVPeV3NPD8',
#  'https://www.youtube.com/watch?v=Haup_kmsibM',
#  'https://www.youtube.com/shorts/CwAfrMnXOv0',
#  'https://www.youtube.com/watch?v=psLBuEJlCzs',
#  'https://www.youtube.com/watch?v=ta1gvU5zCFo',
#  'https://www.youtube.com/watch?v=8GbkGbjNLAc',
#  'https://www.youtube.com/watch?v=fjwPEMruAac',
#  'https://www.youtube.com/watch?v=RpSnv44qtP8',
#  'https://www.youtube.com/watch?v=IXxRCjHsw1Q',
#  'https://www.youtube.com/watch?v=e8s2800uRns',
#  'https://www.youtube.com/watch?v=qjuE4Grt8Wc',
#  'https://www.youtube.com/watch?v=u-qLDZk4o_8',
#  'https://www.youtube.com/watch?v=fZcZQDAey0Q',
#  'https://www.youtube.com/watch?v=LG4drA_EgIs',
#  'https://www.youtube.com/watch?v=kPeJLafIpzA',
#  'https://www.youtube.com/watch?v=xIGANo_AB5E',
#  'https://www.youtube.com/watch?v=7N-Sell-oqM',
#  'https://www.youtube.com/watch?v=WUiqW_Hx6p0',
#  'https://www.youtube.com/watch?v=7bER_FZj7Lc',
#  'https://www.youtube.com/watch?v=P5wzD4r1lNw',
#  'https://www.youtube.com/watch?v=Jc3c-DoCGrM',
#  'https://www.youtube.com/watch?v=0mJS37r9xhA',
#  'https://www.youtube.com/watch?v=8UrkE9uoc-s',
#  'https://www.youtube.com/watch?v=dd8BvhIDy4g',
#  'https://www.youtube.com/watch?v=rryGfq2-xEo',
#  'https://www.youtube.com/watch?v=Tb80NCZE4z0',
#  'https://www.youtube.com/watch?v=TcUojlc_u58',
#  'https://www.youtube.com/watch?v=Tig3x1VPMSI',
#  'https://www.youtube.com/watch?v=CR82O2adPQU',
#  'https://www.youtube.com/watch?v=SaC9SLppXVo',
#  'https://www.youtube.com/watch?v=AGldv-BiZjg',
#  'https://www.youtube.com/watch?v=Dc1qBiRimGM',
#  'https://www.youtube.com/watch?v=ip3gDWXj38s',
#  'https://www.youtube.com/watch?v=qK5icWP7r80',
#  'https://www.youtube.com/watch?v=vVN_de4VtzE',
#  'https://www.youtube.com/watch?v=zQ7e2svDvJA',
#  'https://www.youtube.com/watch?v=d4Tc_yYMEZU',
#  'https://www.youtube.com/watch?v=96-B1O37Bqc',
#  'https://www.youtube.com/watch?v=-daxID6076g',
#  'https://www.youtube.com/watch?v=_jC64T6FwpQ',
#  'https://www.youtube.com/watch?v=rlJO863sX0Q',
#  'https://www.youtube.com/watch?v=mgeiukTCB5o',
#  'https://www.youtube.com/watch?v=Rf2ec-NfN_I',
#  'https://www.youtube.com/watch?v=PPo81r6y0Jk',
#  'https://www.youtube.com/watch?v=PTn_jdg8w7o',
#  'https://www.youtube.com/shorts/Tu-cniNYEhM',
#  'https://www.youtube.com/watch?v=wijLBb58lQM',
#  'https://www.youtube.com/watch?v=2xOI2KnOPM0',
#  'https://www.youtube.com/watch?v=kNGiIaCLZLo',
#  'https://www.youtube.com/watch?v=YmxonzmWftc',
#  'https://www.youtube.com/shorts/zU6_4ksWYLo',
#  'https://www.youtube.com/watch?v=S6E4CiP2wTE',
#  'https://www.youtube.com/watch?v=7a1oq51m7hM',
#  'https://www.youtube.com/watch?v=RVfbffnMx14',
#  'https://www.youtube.com/watch?v=1m9coFWKq6w',
#  'https://www.youtube.com/watch?v=0LCX0hvHV2k',
#  'https://www.youtube.com/watch?v=LlyKy6pktFc',
#  'https://www.youtube.com/watch?v=MfJw7Q8vAk0',
#  'https://www.youtube.com/watch?v=KJjxiddD-fk',
#  'https://www.youtube.com/watch?v=EbR61KM0jPk',
#  'https://www.youtube.com/watch?v=UdXIOi0IC_E',
#  'https://www.youtube.com/watch?v=zoSol4veLSk',
#  'https://www.youtube.com/watch?v=7aR90QGgVgg',
#  'https://www.youtube.com/watch?v=AEjHTGZFT2Y',
#  'https://www.youtube.com/watch?v=cSUTpVaeXdI',
#  'https://www.youtube.com/watch?v=6rYFV8TBHa8',
#  'https://www.youtube.com/watch?v=xCfm4zB7_y0',
#  'https://www.youtube.com/watch?v=HukCxyIXD8M',
#  'https://www.youtube.com/watch?v=6wA-1-hit_8',
#  'https://www.youtube.com/watch?v=C_0_iBNKe_c',
#  'https://www.youtube.com/watch?v=KABROhJ7NzY',
#  'https://www.youtube.com/watch?v=a5hbC1HbiwE',
#  'https://www.youtube.com/watch?v=QzpDaAlJ-ZM',
#  'https://www.youtube.com/watch?v=jF99enh3_to',
#  'https://www.youtube.com/watch?v=CGQN0r4YUhU',
#  'https://www.youtube.com/watch?v=k-Zv5R_vpxo',
#  'https://www.youtube.com/watch?v=JLVvWSSEkaU',
#  'https://www.youtube.com/watch?v=Q77oZsZWeOw',
#  'https://www.youtube.com/watch?v=q-fK9Gq7xG0',
#  'https://www.youtube.com/watch?v=M-dzhJSRhFY',
#  'https://www.youtube.com/watch?v=fN9CuM-sXZY',
#  'https://www.youtube.com/watch?v=zHY8RaRvy0c',
#  'https://www.youtube.com/watch?v=vsITHG5ROo8',
#  'https://www.youtube.com/watch?v=YN9uFhz0SI4',
#  'https://www.youtube.com/watch?v=03m3pbd49FI',
#  'https://www.youtube.com/watch?v=MjsPZjXn3u0',
#  'https://www.youtube.com/watch?v=V3V91gyyEv0',
#  'https://www.youtube.com/watch?v=fLH_3aEPd3g',
#  'https://www.youtube.com/watch?v=y8f8FXZBEwk',
#  'https://www.youtube.com/watch?v=tuVCyjEcgdE',
#  'https://www.youtube.com/watch?v=HB-GRcpw_Bw',
#  'https://www.youtube.com/watch?v=aPJJX7kmpKg',
#  'https://www.youtube.com/watch?v=_j-CDfz5YTw',
#  'https://www.youtube.com/watch?v=G297XYfGglc',
#  'https://www.youtube.com/watch?v=xZRn3L1ks6A',
#  'https://www.youtube.com/watch?v=VT_tWPthvyk',
#  'https://www.youtube.com/watch?v=r14qZonSGYA',
#  'https://www.youtube.com/watch?v=KrFFuuocDfQ',
#  'https://www.youtube.com/watch?v=y7xLW2NIrAo',
#  'https://www.youtube.com/watch?v=hStOBeBDR9M',
#  'https://www.youtube.com/watch?v=2ttePk9qnkk',
#  'https://www.youtube.com/watch?v=6nj9jpe3qHU',
#  'https://www.youtube.com/watch?v=90ITmAFW4Qo',
#  'https://www.youtube.com/watch?v=cHP4_gQGdH4',
#  'https://www.youtube.com/watch?v=Le2q-Q96y4M',
#  'https://www.youtube.com/watch?v=U-LS2uohTk8',
#  'https://www.youtube.com/watch?v=gFHEfhDIyb0',
#  'https://www.youtube.com/watch?v=P_IY8Rg8oDI',
#  'https://www.youtube.com/watch?v=eXEXVyhbHDw',
#  'https://www.youtube.com/watch?v=OmAu_ksbjWE',
#  'https://www.youtube.com/watch?v=7e6hrH70AoI',
#  'https://www.youtube.com/watch?v=1oyC_kEphx4',
#  'https://www.youtube.com/watch?v=HSKapM5rssg',
#  'https://www.youtube.com/watch?v=J00OBs5E0j0',
#  'https://www.youtube.com/watch?v=Dy3glmWAaZQ',
#  'https://www.youtube.com/watch?v=47jL4lBBrkI',
#  'https://www.youtube.com/watch?v=3NLI3FWeQ2g',
#  'https://www.youtube.com/watch?v=ONaUSIzQVO0',
#  'https://www.youtube.com/watch?v=fYofNZNhp_Q',
#  'https://www.youtube.com/watch?v=wcntndKw8R0',
#  'https://www.youtube.com/watch?v=hAdgrlvu6kQ',
#  'https://www.youtube.com/watch?v=GMFI76F641Y',
#  'https://www.youtube.com/watch?v=bsKX33_IRVs',
#  'https://www.youtube.com/watch?v=dXis10rZ7Pk',
#  'https://www.youtube.com/watch?v=HJUrFUBlfXw',
#  'https://www.youtube.com/watch?v=fcHlFZzsuyc',
#  'https://www.youtube.com/watch?v=nfsL4Pysu2Q',
#  'https://www.youtube.com/watch?v=S17-kYaDZX8',
#  'https://www.youtube.com/watch?v=5SAAeakwRU0',
#  'https://www.youtube.com/watch?v=Ob26iR0RwbQ',
#  'https://www.youtube.com/watch?v=jVmF2Ik8-3Q',
#  'https://www.youtube.com/watch?v=H7GNSIibBPA',
#  'https://www.youtube.com/watch?v=iZgL0XFDipM',
#  'https://www.youtube.com/watch?v=AMWcodGPe_M',
#  'https://www.youtube.com/watch?v=Oocu5R8Jz6Y',
#  'https://www.youtube.com/watch?v=Zyyj7GzaVWY',
#  'https://www.youtube.com/watch?v=AvbR7lj5_Ho',
#  'https://www.youtube.com/watch?v=xQScc8s2ONk',
#  'https://www.youtube.com/watch?v=XiwEvVz2Z9o',
#  'https://www.youtube.com/watch?v=fjfl34E8SEw',
#  'https://www.youtube.com/watch?v=OkCO8HF62u8',
#  'https://www.youtube.com/watch?v=ycurx-zs5nY',
#  'https://www.youtube.com/watch?v=2cxkYtNRKXU',
#  'https://www.youtube.com/watch?v=rrVD-YW7_M8',
#  'https://www.youtube.com/watch?v=OAoqXAbr_W4',
#  'https://www.youtube.com/watch?v=EKzpUhIeRak',
#  'https://www.youtube.com/watch?v=stY1cqvWNzA',
#  'https://www.youtube.com/watch?v=rPBIVvg5VxI',
#  'https://www.youtube.com/watch?v=zzRJPtujBfk',
#  'https://www.youtube.com/watch?v=mCdsydvyc3A',
#  'https://www.youtube.com/watch?v=6kEvv1LmrZk',
#  'https://www.youtube.com/watch?v=i51cJ81F-QQ',
#  'https://www.youtube.com/watch?v=ocuphe7zpWg',
#  'https://www.youtube.com/watch?v=bF_PZh-Pk58',
#  'https://www.youtube.com/watch?v=QhMUDvby-Fo',
#  'https://www.youtube.com/watch?v=nw8_PrfKi70',
#  'https://www.youtube.com/watch?v=MIodPUXfi30',
#  'https://www.youtube.com/watch?v=bYA1SPxT4s4',
#  'https://www.youtube.com/watch?v=EX0yPDL4TRM',
#  'https://www.youtube.com/watch?v=nt2MmTMUVVo',
#  'https://www.youtube.com/watch?v=A3qsFsSpDEM',
#  'https://www.youtube.com/watch?v=G8gEkIN-NeY',
#  'https://www.youtube.com/watch?v=MZ3v2xOtMD8',
#  'https://www.youtube.com/watch?v=I_OemtDA3VA',
#  'https://www.youtube.com/watch?v=dMx-hA8B_tA',
#  'https://www.youtube.com/watch?v=mDdtsPZNxYw',
#  'https://www.youtube.com/watch?v=2xJcUmQlP4I',
#  'https://www.youtube.com/watch?v=fT8puM626tQ',
#  'https://www.youtube.com/watch?v=ZCpmnEWA0pg',
#  'https://www.youtube.com/watch?v=t9b9jm3FhGE',
#  'https://www.youtube.com/watch?v=w76QntlsqO0',
#  'https://www.youtube.com/watch?v=ejlbygPTeVI',
#  'https://www.youtube.com/watch?v=lQCgFX2Dihw',
#  'https://www.youtube.com/watch?v=bXZTOQSHMzw',
#  'https://www.youtube.com/watch?v=dTyqwOeftMQ',
#  'https://www.youtube.com/watch?v=v41h8bXbJPI',
#  'https://www.youtube.com/watch?v=_FpYrfclU54',
#  'https://www.youtube.com/watch?v=yUnobjFBmfA',
#  'https://www.youtube.com/watch?v=VmzLUuMWzXw',
#  'https://www.youtube.com/watch?v=mmQ7PmDo2fQ',
#  'https://www.youtube.com/watch?v=Jo2H5y1n2hk',
#  'https://www.youtube.com/watch?v=QszSr8nJ9RI',
#  'https://www.youtube.com/watch?v=w2ChYm8fSNg',
#  'https://www.youtube.com/watch?v=K6j7ttSTOZE',
#  'https://www.youtube.com/watch?v=RXhVKjPYzps',
#  'https://www.youtube.com/watch?v=_BlROv6Wqq4',
#  'https://www.youtube.com/watch?v=PwgqtWWyUyU',
#  'https://www.youtube.com/watch?v=wfN5QcONbXU',
#  'https://www.youtube.com/watch?v=zh4so7wYj-U',
#  'https://www.youtube.com/watch?v=_U23zBH18Cw',
#  'https://www.youtube.com/watch?v=72Z6pi0U4uU',
#  'https://www.youtube.com/watch?v=ardyye4J66Q',
#  'https://www.youtube.com/watch?v=Z6i0M-xmdNw',
#  'https://www.youtube.com/watch?v=UCtQuJWEV5s',
#  'https://www.youtube.com/watch?v=WlQdJ9OfnQI',
#  'https://www.youtube.com/watch?v=-BSNQa4sddA',
#  'https://www.youtube.com/watch?v=apyCcsteKmQ',
#  'https://www.youtube.com/watch?v=LXSGUUYAMEo',
#  'https://www.youtube.com/watch?v=7fDWcfCWztA',
#  'https://www.youtube.com/watch?v=Btt4ZgaOE30',
#  'https://www.youtube.com/watch?v=eTHkFCnB_nQ',
#  'https://www.youtube.com/watch?v=GqWyfyUS0hY',
#  'https://www.youtube.com/watch?v=d1PcjnyWwCY',
#  'https://www.youtube.com/watch?v=naBbbT8pwiE',
#  'https://www.youtube.com/shorts/05_oJQo-xgQ',
#  'https://www.youtube.com/watch?v=87ZfvYMOSS0',
#  'https://www.youtube.com/watch?v=3RvBKU7cuK0',
#  'https://www.youtube.com/watch?v=wJBmX1svTy0',
#  'https://www.youtube.com/watch?v=cnI5Iy890wQ',
#  'https://www.youtube.com/watch?v=qpVhYxXSe6Q',
#  'https://www.youtube.com/watch?v=iV47fOH4R3k',
#  'https://www.youtube.com/watch?v=1dh4pffxhOQ',
#  'https://www.youtube.com/watch?v=ql2_mQHaULA',
#  'https://www.youtube.com/watch?v=l7nsA23_uPc',
#  'https://www.youtube.com/watch?v=MgNakgkvyJ0',
#  'https://www.youtube.com/watch?v=4c-851mQdxY',
#  'https://www.youtube.com/watch?v=dTS4lN2xxzI',
#  'https://www.youtube.com/watch?v=L1I4_n2JN4Q',
#  'https://www.youtube.com/watch?v=zixrQgOqNr8',
#  'https://www.youtube.com/watch?v=JwkrenUb98w',
#  'https://www.youtube.com/watch?v=DmPBzZ6K90w',
#  'https://www.youtube.com/watch?v=vxkt5u9hJtc',
#  'https://www.youtube.com/watch?v=T2r26KuA-ew',
#  'https://www.youtube.com/watch?v=oQmGQsd23oY',
#  'https://www.youtube.com/watch?v=-OZQSg1TU34',
#  'https://www.youtube.com/watch?v=_P-Tu3S6jTA',
#  'https://www.youtube.com/watch?v=b6H-qIPuUzs',
#  'https://www.youtube.com/watch?v=OwMnbTV1Td4',
#  'https://www.youtube.com/watch?v=obx-wLlRPIE',
#  'https://www.youtube.com/watch?v=4Yzm9f543nU',
#  'https://www.youtube.com/watch?v=pdriYyi6_Jo',
#  'https://www.youtube.com/watch?v=iLFxe9N77Zc',
#  'https://www.youtube.com/watch?v=CDn29DfveD4',
#  'https://www.youtube.com/watch?v=n2y2gBW8DJs',
#  'https://www.youtube.com/watch?v=7P8Vx0-GKSU',
#  'https://www.youtube.com/watch?v=Q8pNqZiTrys',
#  'https://www.youtube.com/watch?v=YvEN8uHAL54',
#  'https://www.youtube.com/watch?v=ud2PY6iO3qg',
#  'https://www.youtube.com/watch?v=Cgg3nmW_N74',
#  'https://www.youtube.com/watch?v=tatX0GnhSg8',
#  'https://www.youtube.com/watch?v=9r5mkKtLV30',
#  'https://www.youtube.com/watch?v=G1XoX2WQ_wo',
#  'https://www.youtube.com/watch?v=SgZwN3PAT7Y',
#  'https://www.youtube.com/watch?v=o0N_5hmrzAY',
#  'https://www.youtube.com/watch?v=TfwYG7-SPoU',
#  'https://www.youtube.com/watch?v=wXeZ38NJPyM',
#  'https://www.youtube.com/watch?v=8Q2yKkFY2Wc',
#  'https://www.youtube.com/watch?v=4HQ_790OleU',
#  'https://www.youtube.com/watch?v=yHRMOZnXNgw',
#  'https://www.youtube.com/watch?v=Y3a7dMrESFk',
#  'https://www.youtube.com/watch?v=JJMLIqYQ7Lk',
#  'https://www.youtube.com/watch?v=N_2RisLijHg',
#  'https://www.youtube.com/watch?v=RX0c7SdK_ik',
#  'https://www.youtube.com/watch?v=Y-I0PzMQNHg',
#  'https://www.youtube.com/watch?v=-a0LrRTpz3c',
#  'https://www.youtube.com/watch?v=9I9WdgX1BdQ',
#  'https://www.youtube.com/watch?v=p-3xlnRyWbE',
#  'https://www.youtube.com/watch?v=aOCGgQ-GXTY',
#  'https://www.youtube.com/watch?v=YW7ieT68Hz0',
#  'https://www.youtube.com/watch?v=5vp-TpIORIM',
#  'https://www.youtube.com/shorts/gZVBBuiQoM4',
#  'https://www.youtube.com/watch?v=3_9TdGwiK_A',
#  'https://www.youtube.com/watch?v=7CMsOn1fgdA',
#  'https://www.youtube.com/watch?v=8s7IZTUoZls',
#  'https://www.youtube.com/watch?v=rePDghzFruY',
#  'https://www.youtube.com/shorts/ElXUtwVGFaU',
#  'https://www.youtube.com/watch?v=EsXhqSplu4w',
#  'https://www.youtube.com/watch?v=HhOriPlr9ng',
#  'https://www.youtube.com/watch?v=IBXNZ_uw6Gs',
#  'https://www.youtube.com/watch?v=y0D7xNMjPsQ',
#  'https://www.youtube.com/watch?v=x5UOyAb9QXk',
#  'https://www.youtube.com/watch?v=wFB5Gl8dYS0',
#  'https://www.youtube.com/watch?v=EUjG2vz9Xvc',
#  'https://www.youtube.com/watch?v=sfsNiKzIoMg',
#  'https://www.youtube.com/watch?v=Iu5pQziM5p8',
#  'https://www.youtube.com/watch?v=6h7kn64yHfM',
#  'https://www.youtube.com/watch?v=HHRfryH4K1I',
#  'https://www.youtube.com/watch?v=XJeFHKgjH6s',
#  'https://www.youtube.com/watch?v=tj9crg59tpc',
#  'https://www.youtube.com/watch?v=jvgJJ2rO8TM',
#  'https://www.youtube.com/shorts/YbbEXamMW3c',
#  'https://www.youtube.com/watch?v=kvA-YFGExww',
#  'https://www.youtube.com/watch?v=47wAXHIKr5A',
#  'https://www.youtube.com/watch?v=MbXKEx7_MMc',
#  'https://www.youtube.com/watch?v=9F_bT5V9JMs',
#  'https://www.youtube.com/watch?v=jUUXmoqFOtQ',
#  'https://www.youtube.com/watch?v=SzLpKOZtZRE',
#  'https://www.youtube.com/watch?v=xR5o1AzDScU',
#  'https://www.youtube.com/watch?v=9kdZFdh4gtU',
#  'https://www.youtube.com/watch?v=R9JhyYfTWps',
#  'https://www.youtube.com/watch?v=ZNdot7oXx-I',
#  'https://www.youtube.com/watch?v=_TR5AVScab8',
#  'https://www.youtube.com/watch?v=shGUmiqWWK4',
#  'https://www.youtube.com/watch?v=HYtuPqpoiMU',
#  'https://www.youtube.com/watch?v=Sx_Rv_jKdK0',
#  'https://www.youtube.com/watch?v=wqCeZV-6wrg',
#  'https://www.youtube.com/watch?v=PmqLwnqRorY',
#  'https://www.youtube.com/watch?v=6oK0qfVFxnU',
#  'https://www.youtube.com/watch?v=HzfQ05JVkKI',
#  'https://www.youtube.com/watch?v=l4K-Tg8yeXg',
#  'https://www.youtube.com/watch?v=TNpcH03z-8w',
#  'https://www.youtube.com/watch?v=l_f9MoV4QxE',
#  'https://www.youtube.com/watch?v=KgiEjRqyOqY',
#  'https://www.youtube.com/watch?v=cQZgb80j2i0',
#  'https://www.youtube.com/watch?v=tPVUwJFELVw',
#  'https://www.youtube.com/watch?v=DvKlEV_ez7k',
#  'https://www.youtube.com/watch?v=aoaSFYY_TJ4',
#  'https://www.youtube.com/watch?v=g9P8ih3pzLU',
#  'https://www.youtube.com/watch?v=vYMPUfff4T8',
#  'https://www.youtube.com/watch?v=729IHXFhpyo',
#  'https://www.youtube.com/watch?v=usLRZhYh__Q',
#  'https://www.youtube.com/watch?v=sDEAY5yrKyA',
#  'https://www.youtube.com/watch?v=6nhjaBcZE6Y',
#  'https://www.youtube.com/watch?v=4R39JiYGxco',
#  'https://www.youtube.com/watch?v=OUtdKUVioWs',
#  'https://www.youtube.com/watch?v=YQww-TTHYQo',
#  'https://www.youtube.com/watch?v=Ja8B9ks-McY',
#  'https://www.youtube.com/watch?v=gxl-fkiu_lk',
#  'https://www.youtube.com/watch?v=qU2Q3nFuFw0',
#  'https://www.youtube.com/watch?v=umWXIbicPXs',
#  'https://www.youtube.com/watch?v=PfgOA9W0cKs',
#  'https://www.youtube.com/watch?v=fLVDMCMi4VI',
#  'https://www.youtube.com/watch?v=6-AIEs-9l0w',
#  'https://www.youtube.com/watch?v=qgAdKKXbGtA',
#  'https://www.youtube.com/watch?v=ZZKpbuR_N7M',
#  'https://www.youtube.com/shorts/wdcovHyzQt0',
#  'https://www.youtube.com/watch?v=kYNtAsRa6rQ',
#  'https://www.youtube.com/watch?v=sMGZHW_nREk',
#  'https://www.youtube.com/watch?v=8UunWR9NGRE',
#  'https://www.youtube.com/watch?v=fpDWiYR__EI',
#  'https://www.youtube.com/watch?v=ZzCQ8S4pw-0',
#  'https://www.youtube.com/watch?v=RrJNFLQIp5k',
#  'https://www.youtube.com/watch?v=krUcAn52wtM',
#  'https://www.youtube.com/watch?v=7UJECim5C8s',
#  'https://www.youtube.com/watch?v=l-rxrIVWr6Q',
#  'https://www.youtube.com/watch?v=2SWJN7rU_Ew',
#  'https://www.youtube.com/watch?v=Q3tYT7N5DpI',
#  'https://www.youtube.com/watch?v=zpNwJvrliRc',
#  'https://www.youtube.com/watch?v=m4PfFjv8WAw',
#  'https://www.youtube.com/watch?v=jxhaNJhU-hE',
#  'https://www.youtube.com/watch?v=nekeQ4shxn0',
#  'https://www.youtube.com/watch?v=X3mZah-ZLgU',
#  'https://www.youtube.com/watch?v=L624TIIqmsk',
#  'https://www.youtube.com/watch?v=LgfhpCh4-TM',
#  'https://www.youtube.com/watch?v=HHyeN9pcoRE',
#  'https://www.youtube.com/watch?v=rBYe7riHF4w',
#  'https://www.youtube.com/watch?v=3EfrKZbjQMk',
#  'https://www.youtube.com/watch?v=X2cW0-stYHA',
#  'https://www.youtube.com/watch?v=wNmH0MaR2Cs',
#  'https://www.youtube.com/watch?v=Do9jfoJGUmQ',
#  'https://www.youtube.com/watch?v=cLbLva3bL2Q',
#  'https://www.youtube.com/watch?v=fOqPw2uR0OA',
#  'https://www.youtube.com/watch?v=RsGI2Mf1Oqk',
#  'https://www.youtube.com/watch?v=fIAdNQUUCHo',
#  'https://www.youtube.com/watch?v=QkDCj-PTVjU',
#  'https://www.youtube.com/watch?v=XZedvjCrUVk',
#  'https://www.youtube.com/watch?v=ZSgb_BWTll0',
#  'https://www.youtube.com/watch?v=5AQQ_paUDm4',
#  'https://www.youtube.com/watch?v=VQU3cOmtqRE',
#  'https://www.youtube.com/watch?v=9GWlWU-Vb5A',
#  'https://www.youtube.com/watch?v=Ewi2tjkLto0',
#  'https://www.youtube.com/watch?v=YYwhps3Ty2Q',
#  'https://www.youtube.com/watch?v=kCoAbAQH4cM',
#  'https://www.youtube.com/watch?v=1Yp4WJJ30bs',
#  'https://www.youtube.com/watch?v=soE3SDgcAn4',
#  'https://www.youtube.com/watch?v=DoyyW4o2uEU',
#  'https://www.youtube.com/watch?v=Cimbt_vHhJA',
#  'https://www.youtube.com/watch?v=4_Vm5_ccfQs',
#  'https://www.youtube.com/watch?v=2VnbhPU6f6Q',
#  'https://www.youtube.com/watch?v=kEzUpODNBS8',
#  'https://www.youtube.com/watch?v=Y_vDdLXsN1E',
#  'https://www.youtube.com/shorts/0bGJ220DrYw',
#  'https://www.youtube.com/watch?v=c1w04iBCKCg',
#  'https://www.youtube.com/watch?v=KwBxul-1HA0',
#  'https://www.youtube.com/watch?v=U0NluACiv1Y',
#  'https://www.youtube.com/watch?v=2FyrRfRprtM',
#  'https://www.youtube.com/watch?v=4QL4A2bLEX0',
#  'https://www.youtube.com/watch?v=IOGojB1T_I4',
#  'https://www.youtube.com/watch?v=b7kN_tHJdEM',
#  'https://www.youtube.com/watch?v=TsO6qUsBzoE',
#  'https://www.youtube.com/watch?v=KWU1d-FX8u8',
#  'https://www.youtube.com/watch?v=bDeyFq1IKyw',
#  'https://www.youtube.com/watch?v=HcNHe5SQ_YE',
#  'https://www.youtube.com/watch?v=HJQ11GIj1us',
#  'https://www.youtube.com/watch?v=fhNAjDs82ZY',
#  'https://www.youtube.com/watch?v=qLrchVjmBrg',
#  'https://www.youtube.com/watch?v=qRgSwB1zGys',
#  'https://www.youtube.com/watch?v=xc8EVInR0oM',
#  'https://www.youtube.com/watch?v=Ma7SnLSj1vs',
#  'https://www.youtube.com/watch?v=btyRysU3QcI',
#  'https://www.youtube.com/watch?v=xBJVjypx7S0',
#  'https://www.youtube.com/watch?v=6zr5YyChkC4',
#  'https://www.youtube.com/watch?v=0dDBlTZFMhM',
#  'https://www.youtube.com/watch?v=u922WOz-Eag',
#  'https://www.youtube.com/watch?v=9Je0sMALt8Y',
#  'https://www.youtube.com/watch?v=CMIn23N3CG4',
#  'https://www.youtube.com/watch?v=YXAX7pOQco8',
#  'https://www.youtube.com/watch?v=W8L_-ws_Fy8',
#  'https://www.youtube.com/watch?v=qQV391Qo9mM',
#  'https://www.youtube.com/watch?v=fdalR7I-Qrc',
#  'https://www.youtube.com/watch?v=Q8iOxpnoaks',
#  'https://www.youtube.com/watch?v=FxYap3qWoQU',
#  'https://www.youtube.com/watch?v=H0BA5gEieak',
#  'https://www.youtube.com/watch?v=FNRH_Tsdmqw',
#  'https://www.youtube.com/watch?v=Guwv5UhlRGQ',
#  'https://www.youtube.com/watch?v=ZUOcfbtYR4c',
#  'https://www.youtube.com/watch?v=5V6QQRZXdho',
#  'https://www.youtube.com/watch?v=BJOL78cQueI',
#  'https://www.youtube.com/shorts/A1GrvnARgCg',
#  'https://www.youtube.com/watch?v=YJm2roteLzI',
#  'https://www.youtube.com/watch?v=lKXgjHcmqG8',
#  'https://www.youtube.com/watch?v=ibbgfdureAc',
#  'https://www.youtube.com/watch?v=leznOIbebZ8',
#  'https://www.youtube.com/watch?v=ONWX9gfHEYg',
#  'https://www.youtube.com/watch?v=WY61DfmpVGk',
#  'https://www.youtube.com/watch?v=JclUcyjqMqI',
#  'https://www.youtube.com/watch?v=G2zji1kDtyo',
#  'https://www.youtube.com/watch?v=1LWCBHXcEEk',
#  'https://www.youtube.com/watch?v=PnSC8htJA5c',
#  'https://www.youtube.com/shorts/i7WwTu79URM',
#  'https://www.youtube.com/shorts/rf1pKQxXmHA',
#  'https://www.youtube.com/watch?v=BZP8MUlPOdw',
#  'https://www.youtube.com/watch?v=65GwD5l9Xic',
#  'https://www.youtube.com/watch?v=OWYJ9Qvanis',
#  'https://www.youtube.com/watch?v=d363QslIHJg',
#  'https://www.youtube.com/watch?v=p1a1daH1-m8',
#  'https://www.youtube.com/watch?v=RdFGKKPoGqk',
#  'https://www.youtube.com/watch?v=5qotm1sIIQI',
#  'https://www.youtube.com/watch?v=PWaPCqeCfeY',
#  'https://www.youtube.com/watch?v=3PBC6gPjhFc',
#  'https://www.youtube.com/watch?v=m-a3FbErfII',
#  'https://www.youtube.com/watch?v=Ozx55jpi5To',
#  'https://www.youtube.com/watch?v=mEVwVPOmml4',
#  'https://www.youtube.com/watch?v=jV_x1Kg_BoA',
#  'https://www.youtube.com/watch?v=ZrGIKuS_HZs',
#  'https://www.youtube.com/watch?v=TQY5h2Ie1Jo',
#  'https://www.youtube.com/watch?v=OrqIdDgI1mM',
#  'https://www.youtube.com/watch?v=7x_IWIbVqDM',
#  'https://www.youtube.com/watch?v=klQmszVBirQ',
#  'https://www.youtube.com/watch?v=vE8Av_v3H_o',
#  'https://www.youtube.com/watch?v=g3g2ibKEW6s',
#  'https://www.youtube.com/watch?v=gDhmLotk38M',
#  'https://www.youtube.com/watch?v=qOhb8_kCQ_8',
#  'https://www.youtube.com/watch?v=Aov2BA4_XEo',
#  'https://www.youtube.com/watch?v=IpsA4Pzp-2Q',
#  'https://www.youtube.com/watch?v=dKPCvIl_Nrs',
#  'https://www.youtube.com/watch?v=V6gtND5XB3Q',
#  'https://www.youtube.com/shorts/WmIVgPqrO9Q',
#  'https://www.youtube.com/watch?v=K2P0ntMY28c',
#  'https://www.youtube.com/watch?v=Sde9XB45rjw',
#  'https://www.youtube.com/watch?v=wLMxcAdZPgk',
#  'https://www.youtube.com/watch?v=tKz-aYZsYZY',
#  'https://www.youtube.com/watch?v=RRyykBye2Bw',
#  'https://www.youtube.com/watch?v=9ro1U4vdoOo',
#  'https://www.youtube.com/watch?v=NccwjOuf9Iw',
#  'https://www.youtube.com/watch?v=2ZtD-LIbn-M',
#  'https://www.youtube.com/watch?v=u_-BdCmrCIk',
#  'https://www.youtube.com/watch?v=MqP0vDhZ5zc',
#  'https://www.youtube.com/watch?v=IooBlnWX3qA',
#  'https://www.youtube.com/watch?v=AiQc3XL6cw8',
#  'https://www.youtube.com/shorts/bNz5U37UiLs',
#  'https://www.youtube.com/watch?v=q67-O_yZmTY',
#  'https://www.youtube.com/watch?v=y8EiQhJTbnw',
#  'https://www.youtube.com/watch?v=dJ6xismLbbY',
#  'https://www.youtube.com/watch?v=RAIIxGQX9V4',
#  'https://www.youtube.com/watch?v=XocSBFUhGMA',
#  'https://www.youtube.com/watch?v=mPqjuJT7OV0',
#  'https://www.youtube.com/watch?v=EMpzCE5CRX4',
#  'https://www.youtube.com/watch?v=y1k6r66RhB4',
#  'https://www.youtube.com/watch?v=3xSmUJTNyZ4',
#  'https://www.youtube.com/watch?v=t49WPsSWAtY',
#  'https://www.youtube.com/watch?v=OXkLZ5tG3T8',
#  'https://www.youtube.com/watch?v=Vql2ia4--aI',
#  'https://www.youtube.com/watch?v=BTMC61TIJ5U',
#  'https://www.youtube.com/watch?v=4cxwiZn4IeA',
#  'https://www.youtube.com/shorts/PVJg-_BZOu0',
#  'https://www.youtube.com/watch?v=X9FFhV3DhZE',
#  'https://www.youtube.com/watch?v=68gldPyL7HA',
#  'https://www.youtube.com/watch?v=W7bdFE2ZLMg',
#  'https://www.youtube.com/watch?v=aqha5AywQMg',
#  'https://www.youtube.com/watch?v=BSZHA-e17Lo',
#  'https://www.youtube.com/watch?v=3UTddnswmNM',
#  'https://www.youtube.com/watch?v=5_wy62qtpa4',
#  'https://www.youtube.com/watch?v=IJzFX1IdChw',
#  'https://www.youtube.com/watch?v=7lDDDEB0cOk',
#  'https://www.youtube.com/watch?v=x9im22SzvCQ',
#  'https://www.youtube.com/watch?v=6ulxaplO8JA',
#  'https://www.youtube.com/watch?v=10hMgdMH7mc',
#  'https://www.youtube.com/watch?v=imAVj4tnbIA',
#  'https://www.youtube.com/watch?v=kjB0KCGyQLg',
#  'https://www.youtube.com/watch?v=iHLUFEDyKpQ',
#  'https://www.youtube.com/watch?v=Iy_VXnNJqko',
#  'https://www.youtube.com/watch?v=-_tebUcTjaY',
#  'https://www.youtube.com/watch?v=JADg_RoXvOk',
#  'https://www.youtube.com/watch?v=m2FKoA91Rek',
#  'https://www.youtube.com/watch?v=7hYcV5tloqc',
#  'https://www.youtube.com/watch?v=-CL5VJa1fhI',
#  'https://www.youtube.com/watch?v=MC1ett02cnY',
#  'https://www.youtube.com/watch?v=VVgE2JKuXeM',
#  'https://www.youtube.com/watch?v=LVwIJm8XAo8',
#  'https://www.youtube.com/watch?v=l-_wXKRM6MA',
#  'https://www.youtube.com/watch?v=CykpyIMd_WM',
#  'https://www.youtube.com/watch?v=mHK3LCiNU84',
#  'https://www.youtube.com/watch?v=1alHY2Cjve0',
#  'https://www.youtube.com/watch?v=h0vmBKKcXVc',
#  'https://www.youtube.com/watch?v=fkgnxHVoAhI',
#  'https://www.youtube.com/watch?v=AYoLFIT8CSk',
#  'https://www.youtube.com/watch?v=8pVI2gAmcCw',
#  'https://www.youtube.com/watch?v=Y3jKGC4mtaM',
#  'https://www.youtube.com/watch?v=-P_oCIcR3eg',
#  'https://www.youtube.com/watch?v=Yys32GgSNbs',
#  'https://www.youtube.com/watch?v=iQAJNSY0sJw',
#  'https://www.youtube.com/watch?v=aJcdYnL_2BI',
#  'https://www.youtube.com/watch?v=rpgfb6oubMk',
#  'https://www.youtube.com/watch?v=AvaKo7PQsNo',
#  'https://www.youtube.com/watch?v=4lm1e4RTOxY',
#  'https://www.youtube.com/watch?v=9PLy3QiBR_Q',
#  'https://www.youtube.com/watch?v=7nn-ce9VaJs',
#  'https://www.youtube.com/watch?v=k-Eewr7gT0w',
#  'https://www.youtube.com/watch?v=mMg1vEbYNKA',
#  'https://www.youtube.com/watch?v=cbOrT2JOT60',
#  'https://www.youtube.com/watch?v=FWFNrmVSwI4',
#  'https://www.youtube.com/watch?v=47AB3C-Aqn4',
#  'https://www.youtube.com/watch?v=6KA4okqe8BA',
#  'https://www.youtube.com/watch?v=MZAdUat37-8',
#  'https://www.youtube.com/watch?v=_-LUGqkbizs',
#  'https://www.youtube.com/watch?v=dgsvDme2nqc',
#  'https://www.youtube.com/watch?v=WK73n8n2AXU',
#  'https://www.youtube.com/shorts/-pNb4dPIv4g',
#  'https://www.youtube.com/watch?v=32FzuKaG5U8',
#  'https://www.youtube.com/watch?v=1ihCLKquBCQ',
#  'https://www.youtube.com/watch?v=8UEcpdshKj0',
#  'https://www.youtube.com/shorts/GyvGbuHI5YU',
#  'https://www.youtube.com/watch?v=uv7sKic9Mkg',
#  'https://www.youtube.com/watch?v=mbrTIAjNNfE',
#  'https://www.youtube.com/watch?v=PSELAvD8N7U',
#  'https://www.youtube.com/watch?v=EkA8nUoQm_o',
#  'https://www.youtube.com/watch?v=0r71YgSTNFU',
#  'https://www.youtube.com/watch?v=Jlsr86hJdcY',
#  'https://www.youtube.com/watch?v=MMo8nBuQvWU',
#  'https://www.youtube.com/watch?v=nAWHlwOy73k',
#  'https://www.youtube.com/watch?v=ltmLnOr6eOQ',
#  'https://www.youtube.com/watch?v=ZgQzE2-wIYg',
#  'https://www.youtube.com/watch?v=6zK0c5hycHU',
#  'https://www.youtube.com/watch?v=903GmXi-Q9s',
#  'https://www.youtube.com/watch?v=YfHKXv-7st0',
#  'https://www.youtube.com/watch?v=-nuoKH3Ihnc',
#  'https://www.youtube.com/watch?v=0ogm-lpWqvw',
#  'https://www.youtube.com/watch?v=NT0gaLwu4xc',
#  'https://www.youtube.com/watch?v=-uVw8w0Y1VE',
#  'https://www.youtube.com/watch?v=Fm_7X-zbVgI',
#  'https://www.youtube.com/watch?v=epZtkXjuqK0',
#  'https://www.youtube.com/watch?v=7wV45ukwmB4',
#  'https://www.youtube.com/watch?v=R4hxgtg1gE0',
#  'https://www.youtube.com/watch?v=uaIyr8sZ1x0',
#  'https://www.youtube.com/watch?v=Db5JvRu4YiY',
#  'https://www.youtube.com/watch?v=X-FWe3O6tzc',
#  'https://www.youtube.com/watch?v=jRngKB72NXk',
#  'https://www.youtube.com/watch?v=ely_h7QhDVA',
#  'https://www.youtube.com/watch?v=yntk7n7qm3U',
#  'https://www.youtube.com/watch?v=Sv4aV7hk7EM',
#  'https://www.youtube.com/shorts/CnFxY9SkLu0',
#  'https://www.youtube.com/watch?v=PVGcjoHTFsI',
#  'https://www.youtube.com/watch?v=G1crWvyzYME',
#  'https://www.youtube.com/watch?v=LlWYEbvl930',
#  'https://www.youtube.com/watch?v=pz1ZE1mhiPs',
#  'https://www.youtube.com/watch?v=U5GGgaans_E',
#  'https://www.youtube.com/watch?v=p_Toe5Il-74',
#  'https://www.youtube.com/watch?v=IrEo5RCQ0TA',
#  'https://www.youtube.com/watch?v=4NcRwGJ6a78',
#  'https://www.youtube.com/watch?v=7_pXUadcWi8',
#  'https://www.youtube.com/watch?v=5m1qHx9CjBo',
#  'https://www.youtube.com/watch?v=MyLe_7Otvdg',
#  'https://www.youtube.com/watch?v=aWYghxtndWo',
#  'https://www.youtube.com/watch?v=BBbxe1_euW8',
#  'https://www.youtube.com/watch?v=rtnzL8d7iM4',
#  'https://www.youtube.com/watch?v=eGWSwMUAGVM',
#  'https://www.youtube.com/watch?v=IpU7LW3MYsM',
#  'https://www.youtube.com/watch?v=lGCydxkr8h4',
#  'https://www.youtube.com/watch?v=KWwe3D1oacE',
#  'https://www.youtube.com/watch?v=5eGQcXbbZ6Q',
#  'https://www.youtube.com/watch?v=L7TmSAp2u1g',
#  'https://www.youtube.com/watch?v=qogbHx-tkag',
#  'https://www.youtube.com/watch?v=eCnVgLtcj2c',
#  'https://www.youtube.com/watch?v=C5D9sMiaMSE',
#  'https://www.youtube.com/watch?v=mWbj67FCJ-E',
#  'https://www.youtube.com/watch?v=mmHkGvScDuc',
#  'https://www.youtube.com/watch?v=iQPLXN5CPCk',
#  'https://www.youtube.com/watch?v=4lPueW8Alao',
#  'https://www.youtube.com/watch?v=r1jDvrNi8ro',
#  'https://www.youtube.com/watch?v=_h276eM5_9U',
#  'https://www.youtube.com/watch?v=_o_2NRRdCMg',
#  'https://www.youtube.com/watch?v=OZ6fScfIA1I',
#  'https://www.youtube.com/watch?v=JFW-UYBhLw0',
#  'https://www.youtube.com/watch?v=Xw_eI4v-3m4',
#  'https://www.youtube.com/watch?v=ElA69B5gIUI',
#  'https://www.youtube.com/watch?v=90LaMDuHjLU',
#  'https://www.youtube.com/watch?v=kdnFmvziDAU',
#  'https://www.youtube.com/watch?v=tDsqIHmAClw',
#  'https://www.youtube.com/watch?v=d1HjjAydKNU',
#  'https://www.youtube.com/watch?v=HZf6pv1YmBw',
#  'https://www.youtube.com/watch?v=PY9g_Nn2694',
#  'https://www.youtube.com/watch?v=D6qo8kSDlvE',
#  'https://www.youtube.com/watch?v=hQV50DsLTv4',
#  'https://www.youtube.com/watch?v=bjZc-3qb-QE',
#  'https://www.youtube.com/watch?v=FYytbreuIFY',
#  'https://www.youtube.com/watch?v=ecaQxMYVXek',
#  'https://www.youtube.com/watch?v=mWSu3c_tjYs',
#  'https://www.youtube.com/watch?v=FqX6w-O1ouA',
#  'https://www.youtube.com/watch?v=CQQXE8p1MVc',
#  'https://www.youtube.com/watch?v=zykjPXRQNJQ',
#  'https://www.youtube.com/watch?v=UKzIdnZEiRQ',
#  'https://www.youtube.com/watch?v=PbZ2QoJrrJ4',
#  'https://www.youtube.com/watch?v=5yaJSQkfP2U',
#  'https://www.youtube.com/watch?v=7bgbZm5Mz0M',
#  'https://www.youtube.com/watch?v=Z9kdxYB2uVo',
#  'https://www.youtube.com/watch?v=1J4fj4P4ph8',
#  'https://www.youtube.com/watch?v=KW9JNuATtmw',
#  'https://www.youtube.com/watch?v=zqA2SzwarNg',
#  'https://www.youtube.com/watch?v=tayMq0eRtpI',
#  'https://www.youtube.com/watch?v=EefTjYW-kNk',
#  'https://www.youtube.com/watch?v=a5MLWMBl0iM',
#  'https://www.youtube.com/watch?v=T7Sz-lv7bqo',
#  'https://www.youtube.com/watch?v=vPXqAr-scUA',
#  'https://www.youtube.com/shorts/32SBO68cT4c',
#  'https://www.youtube.com/watch?v=1FaeujGzVMg',
#  'https://www.youtube.com/watch?v=Q41ETQa6bhs',
#  'https://www.youtube.com/watch?v=5YKJ-y2InFg',
#  'https://www.youtube.com/watch?v=XKPSdIbUZuI',
#  'https://www.youtube.com/watch?v=mrYpSUBXeUg',
#  'https://www.youtube.com/watch?v=9inxjKfazoM',
#  'https://www.youtube.com/watch?v=5nXV7mz7W7c',
#  'https://www.youtube.com/watch?v=VYn-v8N4c3I',
#  'https://www.youtube.com/watch?v=R6FMuyOJjYU',
#  'https://www.youtube.com/watch?v=f1lAgxfpwjI',
#  'https://www.youtube.com/watch?v=MzeSBgWsVCQ',
#  'https://www.youtube.com/watch?v=W57F3h0P_4s',
#  'https://www.youtube.com/watch?v=0k74eWTVZnA',
#  'https://www.youtube.com/watch?v=XuPWbfKKoMU',
#  'https://www.youtube.com/watch?v=GZdSPTGP5No',
#  'https://www.youtube.com/watch?v=jShDgcyu9Co',
#  'https://www.youtube.com/watch?v=BxTpahzp2vA',
#  'https://www.youtube.com/watch?v=_HCbP1SZjJ0',
#  'https://www.youtube.com/watch?v=qLSIovVXMzA',
#  'https://www.youtube.com/watch?v=ymsud-vjnNI',
#  'https://www.youtube.com/watch?v=fNmMo2iREWQ',
#  'https://www.youtube.com/shorts/YLbVWo1MJJE',
#  'https://www.youtube.com/watch?v=x73a0DMOozA',
#  'https://www.youtube.com/watch?v=LVwh3keXRBI',
#  'https://www.youtube.com/watch?v=hTwUNmXk54o',
#  'https://www.youtube.com/watch?v=IKj0fdtte90',
#  'https://www.youtube.com/watch?v=ndMZZpW2s1s',
#  'https://www.youtube.com/watch?v=ER6qfeuvUv4',
#  'https://www.youtube.com/watch?v=kTSK3idkpMo',
#  'https://www.youtube.com/watch?v=sCYnje5Yr6g',
#  'https://www.youtube.com/watch?v=j28em1EPE24',
#  'https://www.youtube.com/watch?v=-J_fZ5cVYkw',
#  'https://www.youtube.com/watch?v=2y7I47-ILT8',
#  'https://www.youtube.com/watch?v=pilrIFL5D7M',
#  'https://www.youtube.com/watch?v=1XorDiSYoxA',
#  'https://www.youtube.com/watch?v=KQvcaaatmZg',
#  'https://www.youtube.com/shorts/X-Jagemq1zE',
#  'https://www.youtube.com/watch?v=sDV8ZYyICB4',
#  'https://www.youtube.com/watch?v=Qvyvb96mrN0',
#  'https://www.youtube.com/watch?v=s0ExDjXYxS0',
#  'https://www.youtube.com/watch?v=qBFbW9SMSy0',
#  'https://www.youtube.com/watch?v=L8w1z6wr-3s',
#  'https://www.youtube.com/watch?v=9LmWUw-jHxE',
#  'https://www.youtube.com/watch?v=BTWyhoTezPw',
#  'https://www.youtube.com/watch?v=sQEuEzDd1H4',
#  'https://www.youtube.com/watch?v=0aaQnduCm3c',
#  'https://www.youtube.com/watch?v=W4-zYcuDrUA',
#  'https://www.youtube.com/watch?v=OiKSWuBy-I4',
#  'https://www.youtube.com/watch?v=v2Nz7Nq3lLA',
#  'https://www.youtube.com/watch?v=p-cFL9s_lnU',
#  'https://www.youtube.com/watch?v=I4c0CAJK57w',
#  'https://www.youtube.com/watch?v=-sV7o6LqPqY',
#  'https://www.youtube.com/watch?v=ZLvzIqM4QVo',
#  'https://www.youtube.com/watch?v=QGSfakGuubE',
#  'https://www.youtube.com/watch?v=7U_JW394IIM',
#  'https://www.youtube.com/watch?v=LWxJ77tMhtA',
#  'https://www.youtube.com/watch?v=dtm2M8ubfx0',
#  'https://www.youtube.com/watch?v=bl5bnHVK9x8',
#  'https://www.youtube.com/watch?v=w3omF8xweio',
#  'https://www.youtube.com/watch?v=JneoDmDKlTQ',
#  'https://www.youtube.com/watch?v=QuIOjMWqk-U',
#  'https://www.youtube.com/watch?v=KlcfhrrxxOM',
#  'https://www.youtube.com/watch?v=4Zgz71-mlAg',
#  'https://www.youtube.com/watch?v=uji32Y7Mcno',
#  'https://www.youtube.com/watch?v=CiZc6RpdQas',
#  'https://www.youtube.com/watch?v=lXyDfSr90VM',
#  'https://www.youtube.com/watch?v=7eKHaHlA74w',
#  'https://www.youtube.com/watch?v=HmSEPoKTkdA',
#  'https://www.youtube.com/watch?v=Kkt6A3H5clQ',
#  'https://www.youtube.com/watch?v=DnukP7tmmXI',
#  'https://www.youtube.com/watch?v=vmuAbaTZSS8',
#  'https://www.youtube.com/watch?v=5cZ4xDo7yDo',
#  'https://www.youtube.com/watch?v=75a-aYRT-uo',
#  'https://www.youtube.com/watch?v=8-UyGfDAnac',
#  'https://www.youtube.com/watch?v=9j1ix2UXZVQ',
#  'https://www.youtube.com/watch?v=MRMnes0sk_c',
#  'https://www.youtube.com/shorts/9aFmzOhXT2E',
#  'https://www.youtube.com/watch?v=KWG3TBEi77Q',
#  'https://www.youtube.com/watch?v=nKYphFOp-zM',
#  'https://www.youtube.com/watch?v=ubl3yhxL_us',
#  'https://www.youtube.com/watch?v=xUNCrE8mQmQ',
#  'https://www.youtube.com/watch?v=7Bxc2RYs8RY',
#  'https://www.youtube.com/shorts/qV_yELwOyoE',
#  'https://www.youtube.com/watch?v=KsZI-gTgY04',
#  'https://www.youtube.com/watch?v=y6V9CJrOQ3E',
#  'https://www.youtube.com/watch?v=5CSLpuehUGg',
#  'https://www.youtube.com/watch?v=MhBPiY1XkKk',
#  'https://www.youtube.com/watch?v=tHil5j_wFMw',
#  'https://www.youtube.com/watch?v=LgMqltYPj-I',
#  'https://www.youtube.com/watch?v=5mnP0HnR7uw',
#  'https://www.youtube.com/watch?v=h0dxfghxWW0',
#  'https://www.youtube.com/watch?v=Fn2dsADMNrk',
#  'https://www.youtube.com/watch?v=05xsEWa5N1A',
#  'https://www.youtube.com/watch?v=agPgT9Aou1A',
#  'https://www.youtube.com/watch?v=aiSvrqZLKps',
#  'https://www.youtube.com/watch?v=5wwqtYqPV9Y',
#  'https://www.youtube.com/watch?v=WfkFJLUpVyg',
#  'https://www.youtube.com/watch?v=vubymFhBjHM',
#  'https://www.youtube.com/watch?v=wjYdhpdhs5I',
#  'https://www.youtube.com/watch?v=uTrxYetHCkc',
#  'https://www.youtube.com/watch?v=ynqNIYlVFKo',
#  'https://www.youtube.com/watch?v=waH9pDoJhks',
#  'https://www.youtube.com/watch?v=R-E5MDhIlyk',
#  'https://www.youtube.com/watch?v=9enBuTkrDt8',
#  'https://www.youtube.com/watch?v=RSl5PUgj_2I',
#  'https://www.youtube.com/watch?v=kuhJ8NY2zn8',
#  'https://www.youtube.com/watch?v=aW7PbYHOt8Q',
#  'https://www.youtube.com/watch?v=OSZBz8ZSA9Y',
#  'https://www.youtube.com/watch?v=3ktShH5Mg7g',
#  'https://www.youtube.com/watch?v=-g95jk0hoRY',
#  'https://www.youtube.com/watch?v=xeoOVJduw1w',
#  'https://www.youtube.com/watch?v=h_50JXKovaQ',
#  'https://www.youtube.com/watch?v=pr-GzSbYVXI',
#  'https://www.youtube.com/watch?v=4rFnwFZDytQ',
#  'https://www.youtube.com/watch?v=_PMFyctjdVk',
#  'https://www.youtube.com/watch?v=d0LlUbpVpY0',
#  'https://www.youtube.com/watch?v=TBaX0XcVTx8',
#  'https://www.youtube.com/watch?v=dcy5iySyCuw',
#  'https://www.youtube.com/watch?v=KndIFdz2n9I',
#  'https://www.youtube.com/watch?v=z4isEo-1AZo',
#  'https://www.youtube.com/watch?v=Uhv9vu5otWM',
#  'https://www.youtube.com/watch?v=zNf9jDM7TPA',
#  'https://www.youtube.com/watch?v=1mMTC6qTob0',
#  'https://www.youtube.com/watch?v=pXLQM6IDvwA',
#  'https://www.youtube.com/watch?v=YT3AmLJplcg',
#  'https://www.youtube.com/watch?v=aDmYkhtIXiM',
#  'https://www.youtube.com/watch?v=WCqJQQyJ0-Y',
#  'https://www.youtube.com/watch?v=fh2wCwCyukk',
#  'https://www.youtube.com/watch?v=ov_mf_OhnHM',
#  'https://www.youtube.com/watch?v=oFU6Ht4zRYc',
#  'https://www.youtube.com/watch?v=YGNNNemuYjo',
#  'https://www.youtube.com/watch?v=YoVPfxm6l7E',
#  'https://www.youtube.com/watch?v=Y0o2CzrriRU',
#  'https://www.youtube.com/watch?v=27vmSmW50tc',
#  'https://www.youtube.com/watch?v=zllQIQ-VYV0',
#  'https://www.youtube.com/watch?v=R3M4vwsOpLs',
#  'https://www.youtube.com/watch?v=xk4VQByT2xA',
#  'https://www.youtube.com/watch?v=4Q9GYIJ3bZg',
#  'https://www.youtube.com/watch?v=2EWpIDksYM4',
#  'https://www.youtube.com/watch?v=GfX3nabu6fo',
#  'https://www.youtube.com/watch?v=T9TiX0XPfxY',
#  'https://www.youtube.com/watch?v=aq1g4YR1rRk',
#  'https://www.youtube.com/watch?v=S9WYjsNy82w',
#  'https://www.youtube.com/watch?v=Waus8pQM0NE',
#  'https://www.youtube.com/watch?v=1Lo3ntnGhkI',
#  'https://www.youtube.com/watch?v=r-2acThvuso',
#  'https://www.youtube.com/watch?v=sSO5lmpAGZo',
#  'https://www.youtube.com/watch?v=o1VTihrj9Zs',
#  'https://www.youtube.com/watch?v=_YjP_V8Qy1o',
#  'https://www.youtube.com/watch?v=N4K5_GYn0hU',
#  'https://www.youtube.com/watch?v=34HcyPLZpS0',
#  'https://www.youtube.com/watch?v=8QDbBCJK-oQ',
#  'https://www.youtube.com/watch?v=8rIfxMfY0g0',
#  'https://www.youtube.com/watch?v=RRVw6GSbs7o',
#  'https://www.youtube.com/watch?v=lm72m_rO2K0',
#  'https://www.youtube.com/watch?v=s0dCeq3lKCA',
#  'https://www.youtube.com/watch?v=2Cm1HGWeyfg',
#  'https://www.youtube.com/watch?v=TEHgsq7M8-w',
#  'https://www.youtube.com/watch?v=aDi2Jcu-k7Q',
#  'https://www.youtube.com/watch?v=B8ni-oLxd2s',
#  'https://www.youtube.com/watch?v=qWE6xNxe72w',
#  'https://www.youtube.com/watch?v=WzzQkh79I9w',
#  'https://www.youtube.com/watch?v=i3KjLQU-oX4',
#  'https://www.youtube.com/watch?v=MUzKjpiPMQM',
#  'https://www.youtube.com/watch?v=lc1y_vakmT4',
#  'https://www.youtube.com/shorts/Z0CsPBZ2iVU',
#  'https://www.youtube.com/watch?v=HbaMfLuSSCs',
#  'https://www.youtube.com/watch?v=3rXdxj7uvgM',
#  'https://www.youtube.com/watch?v=KJV_099opkc',
#  'https://www.youtube.com/watch?v=U9-o4gAjsWI',
#  'https://www.youtube.com/watch?v=6R627qMEPzk',
#  'https://www.youtube.com/watch?v=mnuOLhL_YjE',
#  'https://www.youtube.com/watch?v=o1DZRahWi6o',
#  'https://www.youtube.com/watch?v=X-u2LXY99_w',
#  'https://www.youtube.com/watch?v=olhPLQ06qC0',
#  'https://www.youtube.com/watch?v=RLWDmsRO_QE',
#  'https://www.youtube.com/watch?v=CS-UbxkfYP0',
#  'https://www.youtube.com/watch?v=Zl7qjYsFKb4',
#  'https://www.youtube.com/watch?v=vDoB1PNs0e8',
#  'https://www.youtube.com/watch?v=JP9xD5Bj6JU',
#  'https://www.youtube.com/watch?v=DFcwYY74QVk',
#  'https://www.youtube.com/watch?v=3F6Bit7BT3s',
#  'https://www.youtube.com/watch?v=af-fkaYvmAA',
#  'https://www.youtube.com/watch?v=C3az_tMMGe8',
#  'https://www.youtube.com/watch?v=v1pp-Ltv2fU',
#  'https://www.youtube.com/watch?v=4dr-R62laqI',
#  'https://www.youtube.com/watch?v=EpdTuWQi_44',
#  'https://www.youtube.com/watch?v=obF9BKqirp8',
#  'https://www.youtube.com/watch?v=WlEhCTuChOc',
#  'https://www.youtube.com/watch?v=gBqFIWtRaJ4',
#  'https://www.youtube.com/watch?v=yUeQxBjgIKU',
#  'https://www.youtube.com/watch?v=YP6w3mvfFqY',
#  'https://www.youtube.com/watch?v=mCnaeh3BMUg',
#  'https://www.youtube.com/watch?v=XqXmayk_tAk',
#  'https://www.youtube.com/watch?v=4tG9cq1yPtk',
#  'https://www.youtube.com/watch?v=Vrr2kcGnUWI',
#  'https://www.youtube.com/shorts/5mR8vhvdz5g',
#  'https://www.youtube.com/watch?v=swtJNcfQKvw',
#  'https://www.youtube.com/watch?v=qVWCcOcHwfs',
#  'https://www.youtube.com/watch?v=aS8MRJXQ2bk',
#  'https://www.youtube.com/watch?v=OKJZ52n9ZkY',
#  'https://www.youtube.com/watch?v=LTosJupai34',
#  'https://www.youtube.com/watch?v=jXSSNIUhDyE',
#  'https://www.youtube.com/watch?v=msO4eR3A0WE',
#  'https://www.youtube.com/watch?v=kzRhv4kUQfY',
#  'https://www.youtube.com/watch?v=hO6eq-xw4Kw',
#  'https://www.youtube.com/watch?v=qxmeCunoIiQ',
#  'https://www.youtube.com/watch?v=N0Y5oJJxg4A',
#  'https://www.youtube.com/watch?v=hNk3dgmY-Z0',
#  'https://www.youtube.com/watch?v=9kR6So1GgQQ',
#  'https://www.youtube.com/watch?v=GIfdWX4jrEU',
#  'https://www.youtube.com/watch?v=4WfJKklf1Yg',
#  'https://www.youtube.com/watch?v=j5TVPI0CaIA',
#  'https://www.youtube.com/watch?v=ty-pFZibj-c',
#  'https://www.youtube.com/watch?v=8estsPB_RdA',
#  'https://www.youtube.com/watch?v=Z71k9rfJQ1c',
#  'https://www.youtube.com/watch?v=UenKjjfhn1U',
#  'https://www.youtube.com/watch?v=MGYigHNCEEM',
#  'https://www.youtube.com/watch?v=Rc6VRveRDuQ',
#  'https://www.youtube.com/watch?v=9SHxGVF6Sk4',
#  'https://www.youtube.com/watch?v=yoxgUGW-sAE',
#  'https://www.youtube.com/shorts/0vCtHC--lCo',
#  'https://www.youtube.com/watch?v=Ip5Ikpk_gZQ',
#  'https://www.youtube.com/watch?v=qAdvqzFocRM',
#  'https://www.youtube.com/watch?v=bkfoLhL8gQ0',
#  'https://www.youtube.com/watch?v=n-I3w90r5VU',
#  'https://www.youtube.com/watch?v=YxE3sYPbnmw',
#  'https://www.youtube.com/watch?v=pGK5ZzoxwVw',
#  'https://www.youtube.com/watch?v=x2dN6webcN4',
#  'https://www.youtube.com/watch?v=ba-aRaT0lKY',
#  'https://www.youtube.com/watch?v=fLRJ7URITSs',
#  'https://www.youtube.com/watch?v=aMwxWGzdtoo',
#  'https://www.youtube.com/watch?v=THOXcsD32-U',
#  'https://www.youtube.com/watch?v=suqoC2pA5LY',
#  'https://www.youtube.com/watch?v=tW5kijfdgkY',
#  'https://www.youtube.com/watch?v=OsZPUgWUDz4',
#  'https://www.youtube.com/watch?v=Qm-9P64u2e4',
#  'https://www.youtube.com/watch?v=MD0vBoVqk_8',
#  'https://www.youtube.com/watch?v=F4rGXy2Q8a8',
#  'https://www.youtube.com/watch?v=GNg3UXej6K0',
#  'https://www.youtube.com/watch?v=r8RaKzpIuzU',
#  'https://www.youtube.com/watch?v=B1EOUdL5w_M',
#  'https://www.youtube.com/watch?v=qAV-Y1ItCRM',
#  'https://www.youtube.com/watch?v=zybSN7bEMpA',
#  'https://www.youtube.com/watch?v=NVyvOgNoXdM',
#  'https://www.youtube.com/watch?v=yG5_J5-8_ZY',
#  'https://www.youtube.com/watch?v=qLD-iy29BCQ',
#  'https://www.youtube.com/watch?v=tZ4f-FVFAtM',
#  'https://www.youtube.com/watch?v=88-H-zo2-ks',
#  'https://www.youtube.com/watch?v=Z1PueIPk6RQ',
#  'https://www.youtube.com/watch?v=821p5CGBcBw',
#  'https://www.youtube.com/watch?v=JwuX6fqjCdY',
#  'https://www.youtube.com/watch?v=5ry7HzmcUkQ',
#  'https://www.youtube.com/watch?v=LGK_ceKCRM4',
#  'https://www.youtube.com/watch?v=V9DVZLIJ0Io',
#  'https://www.youtube.com/watch?v=UQhEoVgBaQw',
#  'https://www.youtube.com/watch?v=Dn-lu1vWOHE',
#  'https://www.youtube.com/watch?v=r_eVlO2JiY4',
#  'https://www.youtube.com/watch?v=lPop3s_iqqE',
#  'https://www.youtube.com/watch?v=bF01WSj1F2A',
#  'https://www.youtube.com/watch?v=wDCwe6qub-U',
#  'https://www.youtube.com/watch?v=FTYRSnnhSUU',
#  'https://www.youtube.com/watch?v=Vh-TlXsZjmo',
#  'https://www.youtube.com/watch?v=vcBvEUd4rPM',
#  'https://www.youtube.com/watch?v=x1lTsxsSy0Q',
#  'https://www.youtube.com/watch?v=BmACCoiRsMo',
#  'https://www.youtube.com/watch?v=x4Li6JHUUI0',
#  'https://www.youtube.com/watch?v=D6dy5wsWo1E',
#  'https://www.youtube.com/watch?v=j946J9Xpls4',
#  'https://www.youtube.com/watch?v=q-saG_DqLRY',
#  'https://www.youtube.com/watch?v=xUwkknOCr98',
#  'https://www.youtube.com/watch?v=h6932iCBLHM',
#  'https://www.youtube.com/watch?v=mVYED9X0nFo',
#  'https://www.youtube.com/watch?v=XKp4efe9r6c',
#  'https://www.youtube.com/watch?v=Cwx42RsNh74',
#  'https://www.youtube.com/watch?v=H3DzlbKNfyU',
#  'https://www.youtube.com/watch?v=XrVDw6Sxpi4',
#  'https://www.youtube.com/watch?v=tViII0B5VVs',
#  'https://www.youtube.com/watch?v=UfuNm4HqAi4',
#  'https://www.youtube.com/watch?v=3mmJi4B0sM4',
#  'https://www.youtube.com/watch?v=p0mexMt4bBQ',
#  'https://www.youtube.com/watch?v=1nf23a5Goaw',
#  'https://www.youtube.com/watch?v=ouogdOGEVSg',
#  'https://www.youtube.com/watch?v=AhXNXBmjOlA',
#  'https://www.youtube.com/watch?v=mQ4LLGg8ryA',
#  'https://www.youtube.com/watch?v=IPZicPHj-C8',
#  'https://www.youtube.com/watch?v=TfPHjzzxmeY',
#  'https://www.youtube.com/watch?v=63lVFCVVlu0',
#  'https://www.youtube.com/watch?v=gxApn5KGjec',
#  'https://www.youtube.com/watch?v=FT-mQz_alF4',
#  'https://www.youtube.com/watch?v=sGlHXaO-Juk',
#  'https://www.youtube.com/watch?v=dxpmZ75n-QQ',
#  'https://www.youtube.com/watch?v=GVR9oxIFjFc',
#  'https://www.youtube.com/watch?v=DPHlIz7-DWM',
#  'https://www.youtube.com/watch?v=5Q1mJw3w7Mw',
#  'https://www.youtube.com/watch?v=RCqWpAk4lak',
#  'https://www.youtube.com/watch?v=sUmvhN7OEt4',
#  'https://www.youtube.com/watch?v=mBfqG0SWPcY',
#  'https://www.youtube.com/watch?v=jhgsCSVUqGY',
#  'https://www.youtube.com/watch?v=zRJkZ08wlbk',
#  'https://www.youtube.com/watch?v=TSaeK6JUnCU',
#  'https://www.youtube.com/watch?v=nRricdzRtl0',
#  'https://www.youtube.com/watch?v=uAGMtVaZ2U0',
#  'https://www.youtube.com/watch?v=6FgvuUuUheQ',
#  'https://www.youtube.com/watch?v=XRuDWzfZUm0',
#  'https://www.youtube.com/watch?v=Hv9ZEdBdZYo',
#  'https://www.youtube.com/watch?v=U_AwuoG8FoU',
#  'https://www.youtube.com/watch?v=cKbVKtPtKNY',
#  'https://www.youtube.com/watch?v=e-XIBKPNRlw',
#  'https://www.youtube.com/watch?v=Frv-1VEuFdw',
#  'https://www.youtube.com/watch?v=vfTUTylT2c0',
#  'https://www.youtube.com/watch?v=Z1jl_pWiVts',
#  'https://www.youtube.com/watch?v=Ien54o_tCvU',
#  'https://www.youtube.com/watch?v=R0S8OT8nyxA',
#  'https://www.youtube.com/watch?v=-SK27d8sLcs',
#  'https://www.youtube.com/watch?v=2azA_WJCJu8',
#  'https://www.youtube.com/watch?v=YnxbOTkc5Go',
#  'https://www.youtube.com/watch?v=ql7dBMDmoNk',
#  'https://www.youtube.com/watch?v=CrZf13QE7W8',
#  'https://www.youtube.com/watch?v=ajhhECylHZ4',
#  'https://www.youtube.com/watch?v=jGqG3x-Xn9Q',
#  'https://www.youtube.com/watch?v=cssVZGDWM4c',
#  'https://www.youtube.com/watch?v=m1B4vgAPO8A',
#  'https://www.youtube.com/watch?v=CghXjkL-RKo',
#  'https://www.youtube.com/watch?v=AwJStD-RF-A',
#  'https://www.youtube.com/watch?v=FkFQzZTXJiw',
#  'https://www.youtube.com/watch?v=GLFbPtXLRF4',
#  'https://www.youtube.com/watch?v=kOqydKXU678',
#  'https://www.youtube.com/watch?v=FIFLwFgHSgI',
#  'https://www.youtube.com/watch?v=NOrcjDd2evQ',
#  'https://www.youtube.com/watch?v=2nZCQM0DTnk',
#  'https://www.youtube.com/watch?v=vdyKEhzEdrc',
#  'https://www.youtube.com/watch?v=Z8KEgnNYS3g',
#  'https://www.youtube.com/watch?v=bb_bZiHWy-A',
#  'https://www.youtube.com/watch?v=trTIzRjg23U',
#  'https://www.youtube.com/watch?v=NiY6imxLBFU',
#  'https://www.youtube.com/watch?v=0D7l_RXjevs',
#  'https://www.youtube.com/watch?v=8-8Ufq0hRmA',
#  'https://www.youtube.com/watch?v=8aiNHUiJdyo',
#  'https://www.youtube.com/watch?v=JbYa3hlV5C0',
#  'https://www.youtube.com/watch?v=RJ-W3nEKBjA',
#  'https://www.youtube.com/watch?v=5BASwX9yoes',
#  ...]

# %%
scrapes, error_url = [], []
for url in tqdm(urls):
    status, video_id, script = crw.scrape_transcripts(url)
    status, title, channel_name, thumbnail_img, profile_img = crw.parsing_url(url)
    
    if (status == 404) | (status == 403) | (status == -1):
        error_url.append(url)
        
    else:
        scrapes.append([url, title, video_id, channel_name, script, thumbnail_img, profile_img, status])
# Out:
#   0%|          | 0/1036 [00:00<?, ?it/s]

# %%
scrape_df = pd.DataFrame(scrapes, columns=['url', 'video_title', 'video_id', 'youtuber', 'script', 'thumbnail', 'youtuber_profile', 'status'])
scrape_df
# Out:
#                                               url  \
# 0     https://www.youtube.com/watch?v=-MHUrmlE1TQ
# 1     https://www.youtube.com/watch?v=Ze637H39a6s
# 2      https://www.youtube.com/shorts/aT7weMFi-rk
# 3     https://www.youtube.com/watch?v=zlHBymgX_0Q
# 4     https://www.youtube.com/watch?v=9iL6P4oF5Xg
# ...                                           ...
# 1031  https://www.youtube.com/watch?v=n0YSg_G9txM
# 1032  https://www.youtube.com/watch?v=807kZSnugXE
# 1033  https://www.youtube.com/watch?v=l8DIQsK2ynU
# 1034  https://www.youtube.com/watch?v=NZi1gjz7xgs
# 1035  https://www.youtube.com/watch?v=jsh49IzrE30
#
#                                             video_title  \
# 0     fenty skin cherry treat conditioning + strengt...
# 1                  【Switch Sports】美女の真剣勝負。【ホロライブ/紫咲シオン】
# 2     60 Seconds With Val Garland #ValGarland #Nikki...
# 3     REVIEW-DR VANITA RATTAN SKINCARE - (No Affilia...
# 4     आखिरकार जेठालाल को गड़ा इलेक्ट्रॉनिक्स वापिस मि...
# ...                                                 ...
# 1031  Y Yves Saint Laurent – Perfume Masculino – Eau...
# 1032                   Exodo 1-7 | Moises El Libertador
# 1033  SUB) IKEA 2022 New Items Kitchenware Recommend...
# 1034  Recordando el 31 de mayo pasado, presente y pe...
# 1035  Witness recalls tense moments during shooting ...
#
#                                        video_id            youtuber  \
# 0                                   -MHUrmlE1TQ        Alex Greyson
# 1                                   Ze637H39a6s     Shion Ch. 紫咲シオン
# 2     ttps://www.youtube.com/shorts/aT7weMFi-rk       British Vogue
# 3                                   zlHBymgX_0Q  Skincare by Tahwah
# 4                                   9iL6P4oF5Xg          Filmitelly
# ...                                         ...                 ...
# 1031                                n0YSg_G9txM        LCB PERFUMES
# 1032                                807kZSnugXE       Oasis de Amor
# 1033                                l8DIQsK2ynU          Jins'Mommy
# 1034                                NZi1gjz7xgs              CIP tv
# 1035                                jsh49IzrE30       FOX 5 Atlanta
#
#                                                  script  \
# 0     hi everyone my name is alex if you're new to m...
# 1     [Music] [Applause] good morning good morning t...
# 2                                                   NaN
# 3     in today's video i'm going to be reviewing dr ...
# 4     sweeten your mouth I bring good news your shop...
# ...                                                 ...
# 1031  e [Aplausos] [Música] [Aplausos] esse perfume ...
# 1032  el aprendizaje de la palabra para los que se e...
# 1033  मैं आज आईकेईए गया मुझे आईकेईए नीला बैग पसंद है...
# 1034  muy buenas noches colegas y amigos y bienvenid...
# 1035  fire erupts in the parking lot of a busy mcdon...
#
#                                               thumbnail  \
# 0      https://i.ytimg.com/vi/-MHUrmlE1TQ/hqdefault.jpg
# 1      https://i.ytimg.com/vi/Ze637H39a6s/hqdefault.jpg
# 2            https://i.ytimg.com/vi/aT7weMFi-rk/hq2.jpg
# 3     https://i.ytimg.com/vi/zlHBymgX_0Q/maxresdefau...
# 4     https://i.ytimg.com/vi/9iL6P4oF5Xg/maxresdefau...
# ...                                                 ...
# 1031  https://i.ytimg.com/vi/n0YSg_G9txM/maxresdefau...
# 1032   https://i.ytimg.com/vi/807kZSnugXE/hqdefault.jpg
# 1033  https://i.ytimg.com/vi/l8DIQsK2ynU/maxresdefau...
# 1034   https://i.ytimg.com/vi/NZi1gjz7xgs/hqdefault.jpg
# 1035   https://i.ytimg.com/vi/jsh49IzrE30/hqdefault.jpg
#
#                                        youtuber_profile  status
# 0     https://yt3.ggpht.com/WDJFjMzZuGGHS-YYxW_3GvcV...     200
# 1     https://yt3.ggpht.com/AyUL9W0ltc_aJr_MysuZBx8h...     200
# 2     https://yt3.ggpht.com/lb79Cav62zXkSba7QKsyFA28...     200
# 3     https://yt3.ggpht.com/smARDGFlrABy-sSUXZsp7Q15...     200
# 4     https://yt3.ggpht.com/tjkllHcIuRoUdTJf-kRSkGVF...     200
# ...                                                 ...     ...
# 1031  https://yt3.ggpht.com/ytc/AKedOLRGGexCyM8jmcNR...     200
# 1032  https://yt3.ggpht.com/ytc/AKedOLSB0DqbK5D475yD...     200
# 1033  https://yt3.ggpht.com/i8T6LKdMoD0nh23JtNtS-_XJ...     200
# 1034  https://yt3.ggpht.com/ytc/AKedOLRi7hXIdSHBp3H8...     200
# 1035  https://yt3.ggpht.com/apbemrwz_vhLb267r80Txwey...     200
#
# [1036 rows x 8 columns]

# %%
_scrape_df = scrape_df[scrape_df.video_title.notnull() & scrape_df.script.notnull()].reset_index(drop=True)

# 영문, 특수기호(,.!?')만 추출
reg_eng = re.compile('[^a-zA-Z0-9\.\,\?\!\']')
_scrape_df.loc[:, 'script'] = _scrape_df.script.str.replace(reg_eng, ' ').str.replace(' +', ' ')

# 특수기호와 영문 빈도 계산 및 비율 비교를 통한 필터링
_scrape_df_copy = _scrape_df.copy()
_scrape_df_copy.loc[:, 'en'] = _scrape_df_copy.script.str.count('[a-zA-Z]')
_scrape_df_copy.loc[:, 'num'] = _scrape_df_copy.script.str.count('[0-9]')
_scrape_df_copy.loc[:, 'sp_0'] = _scrape_df_copy.script.str.count('\.') 
_scrape_df_copy.loc[:, 'sp_1'] = _scrape_df_copy.script.str.count('\,')
_scrape_df_copy.loc[:, 'sp_2'] = _scrape_df_copy.script.str.count('\?')
_scrape_df_copy.loc[:, 'sp_3'] = _scrape_df_copy.script.str.count('\!')

drop_index = []
for i in range(len(_scrape_df_copy)):
    counts = _scrape_df_copy.iloc[i, -6:].tolist()

    if str(counts[0]) == 'nan':
        pass
    else:
        if counts.index(max(counts)) != 0:
            drop_index.append(i)
        elif counts[0] <= sum(counts[1:]) * 10:
            drop_index.append(i)
        else:
            pass

_scrape_df_copy_ = _scrape_df_copy.drop(drop_index).sort_values('youtuber').reset_index(drop=True)

# Upload table into Database
columns = ['url', 'video_title', 'thumbnail', 'youtuber', 'youtuber_profile', 'script']
upload_df =  _scrape_df_copy_.loc[:, columns]

# %%
upload_df
# Out:
#                                              url  \
# 0    https://www.youtube.com/watch?v=ip3gDWXj38s
# 1    https://www.youtube.com/watch?v=qulrHuPYM3g
# 2    https://www.youtube.com/watch?v=Ien54o_tCvU
# 3    https://www.youtube.com/watch?v=EX0yPDL4TRM
# 4    https://www.youtube.com/watch?v=x9im22SzvCQ
# ..                                           ...
# 903  https://www.youtube.com/watch?v=_HCbP1SZjJ0
# 904  https://www.youtube.com/watch?v=34HcyPLZpS0
# 905  https://www.youtube.com/watch?v=cKbVKtPtKNY
# 906  https://www.youtube.com/watch?v=3NASrEUoMe8
# 907  https://www.youtube.com/watch?v=kPeJLafIpzA
#
#                                            video_title  \
# 0                        In Search Of Golden | SHIMANO
# 1    skincare routine ♡ hydrated and glowy skin - s...
# 2    Drone aids in arrest of armed robbery suspect ...
# 3    SHOCKING VIDEO: Teen, officer and driver injur...
# 4    'Watch out, I have a killer': Man, puppy recov...
# ..                                                 ...
# 903                👾Aritzia haul - 2022 Spring/Summer👾
# 904                   🦧Aritzia try on haul (50% Off) 🦧
# 905  🐋Lululemon try on haul (like a cloud bra/align...
# 906                    LA MER- IS IT REALLY LONG WEAR?
# 907  Best NFTs To Buy | Top 3 NFT Projects With Hug...
#
#                                              thumbnail           youtuber  \
# 0    https://i.ytimg.com/vi/ip3gDWXj38s/maxresdefau...       #RideShimano
# 1    https://i.ytimg.com/vi/qulrHuPYM3g/maxresdefau...            02dolls
# 2     https://i.ytimg.com/vi/Ien54o_tCvU/hqdefault.jpg            11Alive
# 3    https://i.ytimg.com/vi/EX0yPDL4TRM/maxresdefau...  6abc Philadelphia
# 4    https://i.ytimg.com/vi/x9im22SzvCQ/maxresdefau...  6abc Philadelphia
# ..                                                 ...                ...
# 903  https://i.ytimg.com/vi/_HCbP1SZjJ0/maxresdefau...   👽My littlespace👽
# 904  https://i.ytimg.com/vi/34HcyPLZpS0/maxresdefau...   👽My littlespace👽
# 905  https://i.ytimg.com/vi/cKbVKtPtKNY/maxresdefau...   👽My littlespace👽
# 906   https://i.ytimg.com/vi/3NASrEUoMe8/hqdefault.jpg   💄💕XAStrAxBEauTYx
# 907  https://i.ytimg.com/vi/kPeJLafIpzA/maxresdefau...   💎 Ico Investor 💎
#
#                                       youtuber_profile  \
# 0    https://yt3.ggpht.com/ytc/AKedOLQ4aSePzYIKQvlC...
# 1    https://yt3.ggpht.com/Hkei20kxFm3IzLsmhdACWVYt...
# 2    https://yt3.ggpht.com/ytc/AKedOLR_q1u-FxCmrzGp...
# 3    https://yt3.ggpht.com/bVeSeSOK0hwA_Iq4_LuXDVNz...
# 4    https://yt3.ggpht.com/bVeSeSOK0hwA_Iq4_LuXDVNz...
# ..                                                 ...
# 903  https://yt3.ggpht.com/WNiDi4HMYBYsuuta-U5KXLMd...
# 904  https://yt3.ggpht.com/WNiDi4HMYBYsuuta-U5KXLMd...
# 905  https://yt3.ggpht.com/WNiDi4HMYBYsuuta-U5KXLMd...
# 906  https://yt3.ggpht.com/qOMz1XmdoYlVhZ2Sfvjf0maD...
# 907  https://yt3.ggpht.com/bFI9NfS5NmbDjq0TVZkZ7iot...
#
#                                                 script
# 0    Valokuvaajana etsin aina vaikuttavia n kymi . ...
# 1    est tout le monde aujourd'hui on se retrouve p...
# 2    robbery suspects are cornered in broad dayligh...
# 3    surveillance video showing police flying throu...
# 4    residents in cherry hill new jersey are up in ...
# ..                                                 ...
# 903  hello friends today we are going to do this au...
# 904  hello friends today we are going to do an eras...
# 905  hello friends today we are going to do another...
# 906  hi guys how are y'all doing i hope you are ver...
# 907  hey everyone and welcome back to the channel i...
#
# [908 rows x 6 columns]

# %%
upload_df
# Out:
#                                              url  \
# 0    https://www.youtube.com/watch?v=ip3gDWXj38s
# 1    https://www.youtube.com/watch?v=qulrHuPYM3g
# 2    https://www.youtube.com/watch?v=Ien54o_tCvU
# 3    https://www.youtube.com/watch?v=YXAX7pOQco8
# 4    https://www.youtube.com/watch?v=vDoB1PNs0e8
# ..                                           ...
# 941  https://www.youtube.com/watch?v=34HcyPLZpS0
# 942  https://www.youtube.com/watch?v=cKbVKtPtKNY
# 943  https://www.youtube.com/watch?v=_HCbP1SZjJ0
# 944  https://www.youtube.com/watch?v=3NASrEUoMe8
# 945  https://www.youtube.com/watch?v=kPeJLafIpzA
#
#                                            video_title  \
# 0                        In Search Of Golden | SHIMANO
# 1    skincare routine ♡ hydrated and glowy skin - s...
# 2    Drone aids in arrest of armed robbery suspect ...
# 3    나스닥 0.73% 하락! 23억 투자자가 말하는 2022년 하반기 투자 전략! (T...
# 4    Worker attacked at 30th Street Station shares ...
# ..                                                 ...
# 941                   🦧Aritzia try on haul (50% Off) 🦧
# 942  🐋Lululemon try on haul (like a cloud bra/align...
# 943                👾Aritzia haul - 2022 Spring/Summer👾
# 944                    LA MER- IS IT REALLY LONG WEAR?
# 945  Best NFTs To Buy | Top 3 NFT Projects With Hug...
#
#                                              thumbnail           youtuber  \
# 0    https://i.ytimg.com/vi/ip3gDWXj38s/maxresdefau...       #RideShimano
# 1    https://i.ytimg.com/vi/qulrHuPYM3g/maxresdefau...            02dolls
# 2     https://i.ytimg.com/vi/Ien54o_tCvU/hqdefault.jpg            11Alive
# 3     https://i.ytimg.com/vi/YXAX7pOQco8/hqdefault.jpg  5마일_미국주식으로 경제적 자유
# 4    https://i.ytimg.com/vi/vDoB1PNs0e8/maxresdefau...  6abc Philadelphia
# ..                                                 ...                ...
# 941  https://i.ytimg.com/vi/34HcyPLZpS0/maxresdefau...   👽My littlespace👽
# 942  https://i.ytimg.com/vi/cKbVKtPtKNY/maxresdefau...   👽My littlespace👽
# 943  https://i.ytimg.com/vi/_HCbP1SZjJ0/maxresdefau...   👽My littlespace👽
# 944   https://i.ytimg.com/vi/3NASrEUoMe8/hqdefault.jpg   💄💕XAStrAxBEauTYx
# 945  https://i.ytimg.com/vi/kPeJLafIpzA/maxresdefau...   💎 Ico Investor 💎
#
#                                       youtuber_profile  \
# 0    https://yt3.ggpht.com/ytc/AKedOLQ4aSePzYIKQvlC...
# 1    https://yt3.ggpht.com/Hkei20kxFm3IzLsmhdACWVYt...
# 2    https://yt3.ggpht.com/ytc/AKedOLR_q1u-FxCmrzGp...
# 3    https://yt3.ggpht.com/sKz7wGPADBcvQ-k-KRU8QKo8...
# 4    https://yt3.ggpht.com/bVeSeSOK0hwA_Iq4_LuXDVNz...
# ..                                                 ...
# 941  https://yt3.ggpht.com/WNiDi4HMYBYsuuta-U5KXLMd...
# 942  https://yt3.ggpht.com/WNiDi4HMYBYsuuta-U5KXLMd...
# 943  https://yt3.ggpht.com/WNiDi4HMYBYsuuta-U5KXLMd...
# 944  https://yt3.ggpht.com/qOMz1XmdoYlVhZ2Sfvjf0maD...
# 945  https://yt3.ggpht.com/bFI9NfS5NmbDjq0TVZkZ7iot...
#
#                                                 script
# 0    Valokuvaajana etsin aina vaikuttavia n kymi . ...
# 1    est tout le monde aujourd'hui on se retrouve p...
# 2    robbery suspects are cornered in broad dayligh...
# 3     6 9 4 100cm 500 11 16 2 5 4 77 5811 5 1 smp 5...
# 4    custodian at 30th street station who was attac...
# ..                                                 ...
# 941  hello friends today we are going to do an eras...
# 942  hello friends today we are going to do another...
# 943  hello friends today we are going to do this au...
# 944  hi guys how are y'all doing i hope you are ver...
# 945  hey everyone and welcome back to the channel i...
#
# [946 rows x 6 columns]
